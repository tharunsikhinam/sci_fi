# %%
import pandas as pd
import numpy as np

# %%
df_movies_metadata = pd.read_csv('movies_metadata.csv')
# Out:
# /usr/local/Cellar/python/2.7.12/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df_movies_metadata.columns)
# Out:
# Index([u'adult', u'belongs_to_collection', u'budget', u'genres', u'homepage',
#        u'id', u'imdb_id', u'original_language', u'original_title', u'overview',
#        u'popularity', u'poster_path', u'production_companies',
#        u'production_countries', u'release_date', u'revenue', u'runtime',
#        u'spoken_languages', u'status', u'tagline', u'title', u'video',
#        u'vote_average', u'vote_count'],
#       dtype='object')

# %%
df_movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview    ...     release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1  When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2  A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4  Just when George Banks has recovered from his ...    ...       1995-02-10
#
#      revenue runtime                                   spoken_languages  \
# 0  373554033      81           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249     104  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0     101           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156     127           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911     106           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7       5415
# 1                      Jumanji  False          6.9       2413
# 2             Grumpier Old Men  False          6.5         92
# 3            Waiting to Exhale  False          6.1         34
# 4  Father of the Bride Part II  False          5.7        173
#
# [5 rows x 24 columns]

# %%
df_movies_metadata.shape
# Out:
# (45466, 24)

# %%
df_movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.7+ MB

# %%
# Remove features that are not useful
df_movies_metadata = df_movies_metadata.drop(['imdb_id'], axis=1)

# %%
df_movies_metadata[df_movies_metadata['original_title'] != df_movies_metadata['title']][['title', 'original_title']].head()
# Out:
#                         title                    original_title
# 28  The City of Lost Children        La Cité des Enfants Perdus
# 29             Shanghai Triad                         摇啊摇，摇到外婆桥
# 32           Wings of Courage  Guillaumet, les ailes du courage
# 57                The Postman                        Il postino
# 58           The Confessional                  Le confessionnal

# %%
df_movies_metadata = df_movies_metadata.drop('original_title', axis=1)

# %%
df_movies_metadata['revenue'] = df_movies_metadata['revenue'].replace(0, np.nan)

# %%
df_movies_metadata['budget'] = pd.to_numeric(df_movies_metadata['budget'], errors='coerce')
df_movies_metadata['budget'] = df_movies_metadata['budget'].replace(0, np.nan)
df_movies_metadata[df_movies_metadata['budget'].isnull()].shape
# Out:
# (36576, 22)

# %%
# Drop Adult movies
df_movies_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  - Written by Ørnås                                                                                                                   1
# Name: adult, dtype: int64

# %%
df_movies_metadata = df_movies_metadata.drop('adult', axis=1)

# %%
base_poster_url = 'http://image.tmdb.org/t/p/w185/'
df_movies_metadata['poster_path'] = base_poster_url + df_movies_metadata['poster_path']

# %%
# create the year feature
df_movies_metadata['year'] = pd.to_datetime(df_movies_metadata['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
# create the return feature
df_movies_metadata['return'] = df_movies_metadata['revenue'] / df_movies_metadata['budget']
df_movies_metadata[df_movies_metadata['return'].isnull()].shape
# Let's explore our dataset again
df_movies_metadata.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...       NaN
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...       NaN
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id original_language  \
# 0  http://toystory.disney.com/toy-story    862                en
# 1                                   NaN   8844                en
# 2                                   NaN  15602                en
# 3                                   NaN  31357                en
# 4                                   NaN  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  Just when George Banks has recovered from his ...    8.38752
#
#                                          poster_path  \
# 0  http://image.tmdb.org/t/p/w185//rhIRbceoE9lR4v...
# 1  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 2  http://image.tmdb.org/t/p/w185//6ksm1sjKMFLbO7...
# 3  http://image.tmdb.org/t/p/w185//16XOMpEaLWkrcP...
# 4  http://image.tmdb.org/t/p/w185//e64sOI48hQXyru...
#
#                                 production_companies    ...     runtime  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]    ...          81
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...         104
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    ...         101
# 3  [{'name': 'Twentieth Century Fox Film Corporat...    ...         127
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...    ...         106
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year     return
# 0                    Toy Story  False          7.7       5415  1995  12.451801
# 1                      Jumanji  False          6.9       2413  1995   4.043035
# 2             Grumpier Old Men  False          6.5         92  1995        NaN
# 3            Waiting to Exhale  False          6.1         34  1995   5.090760
# 4  Father of the Bride Part II  False          5.7        173  1995        NaN
#
# [5 rows x 23 columns]

# %%
# Filter only on Science Fiction and Fantasy
df_movies_sff = df_movies_metadata[df_movies_metadata['genres'].str.contains("Science Fiction|Fantasy")]
df_movies_sff.shape
# Out:
# (4844, 23)

# %%
# Let's explore our dataset again
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN  65000000
# 23                                                NaN       NaN
# 28                                                NaN  18000000
# 31                                                NaN  29500000
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies    ...    runtime  \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...        104
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...    ...        111
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...    ...        108
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...        129
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...         89
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year    return
# 1                     Jumanji  False          6.9       2413  1995  4.043035
# 23                     Powder  False          6.3        143  1995       NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.096589
# 31             Twelve Monkeys  False          7.4       2470  1995  5.723390
# 33                       Babe  False          6.0        756  1995  8.471164
#
# [5 rows x 23 columns]

# %%
# Sub-genre List
# - alien (Alien)
# - monster (Monster)
# - space (Space Opera)
# - robot (AI/Robot)
# - time_travel (Time Travel)
# - super (Superheroes)
# - dystopian (Dystopian)
# - fantasy (Fantasy)
# - techno (Technology Thriller)
# Approach: Create new column called sub_genres
# if overview column contains word, append that word + '/' to the cell in sub_genres

# Create new column called sub_genres
df_movies_sff['sub_genres'] = ''
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def search(df, *words):  #1
    """
    Return a sub-DataFrame of those rows whose Name column match all the words.
    """
    return df[np.logical_or.reduce([df['overview'].str.contains(word, case='False', na=False) for word in words])]   # 2

# %%
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN  65000000
# 23                                                NaN       NaN
# 28                                                NaN  18000000
# 31                                                NaN  29500000
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies     ...      \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...     ...
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...     ...
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...     ...
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...     ...
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...     ...
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year    return  \
# 1                     Jumanji  False          6.9       2413  1995  4.043035
# 23                     Powder  False          6.3        143  1995       NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.096589
# 31             Twelve Monkeys  False          7.4       2470  1995  5.723390
# 33                       Babe  False          6.0        756  1995  8.471164
#
#     sub_genres
# 1
# 23
# 28
# 31
# 33
#
# [5 rows x 24 columns]

# %%
df_movies_sff.loc[search(df_movies_sff, 'saucer', 'alien', 'life', 'human', 'extraterrestrial', 'ufo', 'parasite'\
                        'meteorite', 'meteor').index, 'sub_genres'] = 'alien/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'luke', 'star', 'spaceship', 'battle', 'interstellar', 'planet', 'enterprise', 'skywalker', 'darth', 'droid'\
                        'earth', 'spock', 'kirk', 'space', 'capt', 'moon', 'spacecraft', 'crew', 'comet', 'mars').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'space/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'cop', 'ai', 'cyborg', 'terminator', 'army', 'android', 'weapon', 'robot', 'intelligence', 'machine').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'robot/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'travel', 'time', 'back', 'frozen').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'time_travel/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'marvel', 'superman', 'superpower', 'super').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'super/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'virus', 'future', 'nuclear', 'city', 'epidemic', 'prison', 'dark', 'murder', 'evil', 'violence', 'experiment'\
                        'totalitarian', 'society', 'post-apocalyptic', 'dystopian', 'experiments').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'dystopian/'

# %%
df_movies_sff.loc[df_movies_sff['genres'].str.contains("Fantasy", case='False', na=False), 'sub_genres'] = df_movies_sff['sub_genres'].astype(str) + 'fantasy/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'frankenstein', 'vampire', 'werewolf', 'shark', 'spider', 'zombie', 'blob', 'creature', 'troll', 'gypsy', 'ape'\
                        'dinosaur', 'jurrasic', 'scientist', 'swamp', 'dinosaurs', 'monster', 'octopus', 'godzilla').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'monster/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'computer', 'cyber', 'matrix', 'chip', 'network', 'serum', 'data', 'virtual', 'reality', 'laser', 'video', 'game'\
                        'player', 'tech').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'techno/'

# %%
df_movies_sff['sub_genres'].value_counts()
# Out:
# fantasy/                                             552
#                                                      378
# robot/fantasy/                                       304
# robot/                                               215
# alien/                                               140
# dystopian/                                           137
# dystopian/fantasy/                                   136
# time_travel/fantasy/                                 115
# robot/dystopian/                                     113
# robot/time_travel/fantasy/                           109
# alien/fantasy/                                       104
# robot/dystopian/fantasy/                             102
# monster/                                              99
# alien/robot/                                          95
# time_travel/                                          93
# space/                                                82
# alien/robot/fantasy/                                  72
# robot/time_travel/                                    58
# robot/time_travel/dystopian/fantasy/                  54
# alien/monster/                                        53
# space/fantasy/                                        52
# alien/dystopian/                                      51
# alien/space/                                          50
# fantasy/monster/                                      50
# time_travel/dystopian/fantasy/                        50
# robot/monster/                                        49
# alien/time_travel/                                    46
# space/robot/fantasy/                                  45
# space/robot/                                          44
# alien/robot/dystopian/                                42
#                                                     ...
# time_travel/super/                                     1
# dystopian/fantasy/techno/                              1
# alien/space/robot/dystopian/fantasy/techno/            1
# dystopian/monster/techno/                              1
# alien/time_travel/dystopian/fantasy/techno/            1
# space/robot/time_travel/super/dystopian/fantasy/       1
# space/robot/dystopian/techno/                          1
# time_travel/super/fantasy/techno/                      1
# alien/space/robot/time_travel/fantasy/techno/          1
# alien/time_travel/fantasy/techno/                      1
# alien/robot/dystopian/monster/techno/                  1
# time_travel/fantasy/monster/techno/                    1
# space/robot/time_travel/dystopian/fantasy/techno/      1
# alien/time_travel/dystopian/fantasy/monster/           1
# space/dystopian/monster/techno/                        1
# space/time_travel/fantasy/monster/                     1
# alien/robot/time_travel/dystopian/fantasy/techno/      1
# alien/robot/time_travel/monster/techno/                1
# alien/space/time_travel/dystopian/monster/techno/      1
# alien/space/dystopian/techno/                          1
# alien/space/dystopian/fantasy/monster/                 1
# robot/time_travel/super/fantasy/                       1
# robot/super/dystopian/                                 1
# space/time_travel/dystopian/techno/                    1
# space/time_travel/super/dystopian/                     1
# super/fantasy/monster/                                 1
# alien/time_travel/monster/techno/                      1
# alien/dystopian/fantasy/techno/                        1
# space/dystopian/fantasy/techno/                        1
# robot/time_travel/dystopian/techno/                    1
# Name: sub_genres, dtype: int64

# %%
# number of empty sub_genres remaining
(df_movies_sff['sub_genres'].values == '').sum()
# Out:
# 378

# %%
# we still need to do some work here... label the rest of the movies with sub_genres
df_movies_sff.loc[df_movies_sff['sub_genres'].values=='']
# Out:
#                                    belongs_to_collection     budget  \
# 475    {'id': 328, 'name': 'Jurassic Park Collection'...   63000000
# 1180   {'id': 529, 'name': 'Wallace & Gromit Collecti...        NaN
# 1322   {'id': 151, 'name': 'Star Trek: The Original S...   35000000
# 1324   {'id': 151, 'name': 'Star Trek: The Original S...   30000000
# 1462   {'id': 259398, 'name': 'Teenage Apocalypse Tri...        NaN
# 1613                                                 NaN    1000000
# 1684                                                 NaN   75000000
# 1917                                                 NaN   15000000
# 1996   {'id': 63043, 'name': 'TRON Collection', 'post...   17000000
# 2010                                                 NaN   10000000
# 2162                                                 NaN    2000000
# 2250   {'id': 374509, 'name': 'Godzilla (Showa) Colle...    1000000
# 2342   {'id': 109609, 'name': 'The Fly Collection', '...   15000000
# 2441                                                 NaN        NaN
# 2543                                                 NaN        NaN
# 2546                                                 NaN        NaN
# 2547                                                 NaN    2000000
# 2548                                                 NaN        NaN
# 2586                                                 NaN  170000000
# 2902   {'id': 98036, 'name': 'Re-Animator Collection'...     900000
# 3073                                                 NaN   90000000
# 3086                                                 NaN        NaN
# 3236                                                 NaN   90000000
# 3351                                                 NaN   20000000
# 3516   {'id': 645, 'name': 'James Bond Collection', '...   34000000
# 3610                                                 NaN    5500000
# 3710                                                 NaN      62000
# 3739   {'id': 223564, 'name': 'The Cell Collection', ...   33000000
# 3740   {'id': 374512, 'name': 'Godzilla (Millennium) ...    1000000
# 3856                                                 NaN   80000000
# ...                                                  ...        ...
# 43439                                                NaN        NaN
# 43450                                                NaN        NaN
# 43455                                                NaN        NaN
# 43480                                                NaN        NaN
# 43665                                                NaN        NaN
# 43904                                                NaN        NaN
# 43963                                                NaN        NaN
# 43993  {'id': 106790, 'name': 'Hooked Collection', 'p...    3500000
# 44002                                                NaN        NaN
# 44094                                                NaN        NaN
# 44103                                                NaN    5000000
# 44173                                                NaN        NaN
# 44209                                                NaN        NaN
# 44251                                                NaN        NaN
# 44271                                                NaN    6000000
# 44301                                                NaN        NaN
# 44344                                                NaN        NaN
# 44345  {'id': 154752, 'name': 'Legend of the Galactic...        NaN
# 44444                                                NaN        NaN
# 44559                                                NaN        NaN
# 44582                                                NaN    5000000
# 44624                                                NaN        NaN
# 44754                                                NaN        NaN
# 44893                                                NaN        NaN
# 44894                                                NaN        NaN
# 44969                                                NaN        NaN
# 45053                                                NaN        NaN
# 45116                                                NaN        NaN
# 45300                                                NaN        NaN
# 45430                                                NaN        NaN
#
#                                                   genres  \
# 475    [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1180   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1322   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1324   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1462   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1613   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 1684            [{'id': 878, 'name': 'Science Fiction'}]
# 1917   [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 1996   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2010   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 2162   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2250   [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 2342   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2441   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2543   [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 2546   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2547   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2548   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2586   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2902   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 3073   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 3086   [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...
# 3236            [{'id': 878, 'name': 'Science Fiction'}]
# 3351   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 3516   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3610   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 3710   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 3739   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 3740   [{'id': 12, 'name': 'Adventure'}, {'id': 27, '...
# 3856   [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# ...                                                  ...
# 43439  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 43450  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 43455           [{'id': 878, 'name': 'Science Fiction'}]
# 43480  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 43665  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 43904  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 43963  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 43993  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 44002           [{'id': 878, 'name': 'Science Fiction'}]
# 44094  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 44103  [{'id': 28, 'name': 'Action'}, {'id': 10749, '...
# 44173  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 44209           [{'id': 878, 'name': 'Science Fiction'}]
# 44251  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 44271  [{'id': 53, 'name': 'Thriller'}, {'id': 10749,...
# 44301  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 44344  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 44345  [{'id': 16, 'name': 'Animation'}, {'id': 878, ...
# 44444  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 44559  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 44582  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 44624  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 44754  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 44893  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 44894  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 44969  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 45053           [{'id': 878, 'name': 'Science Fiction'}]
# 45116  [{'id': 10402, 'name': 'Music'}, {'id': 16, 'n...
# 45300  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 45430  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
#
#                                                 homepage      id  \
# 475                         http://www.jurassicpark.com/     329
# 1180   http://www.wallaceandgromit.com/films/a-grand-...     530
# 1322                                                 NaN     152
# 1324                                                 NaN     172
# 1462                                                 NaN    1811
# 1613                                                 NaN   29938
# 1684   http://www.warnerbros.com/movies/home-entertai...   10153
# 1917                                                 NaN    9424
# 1996                                                 NaN      97
# 2010                                                 NaN    9980
# 2162                                                 NaN   24746
# 2250                                                 NaN    1678
# 2342                                                 NaN    9426
# 2441                                                 NaN   30202
# 2543                                                 NaN   43391
# 2546                                                 NaN   19483
# 2547                                                 NaN    8974
# 2548                                                 NaN   29959
# 2586                                                 NaN    8487
# 2902                                                 NaN    1694
# 3073                                                 NaN   10384
# 3086                                                 NaN   16241
# 3236                                                 NaN    2067
# 3351                                                 NaN     840
# 3516       http://www.mgm.com/view/movie/1292/Moonraker/     698
# 3610                                                 NaN   12611
# 3710                                                 NaN   33468
# 3739                                                 NaN    8843
# 3740                                                 NaN   10643
# 3856                                                 NaN    8870
# ...                                                  ...     ...
# 43439                                                NaN  425487
# 43450                                                NaN  443297
# 43455                                                NaN   31280
# 43480                                                NaN  236053
# 43665                                                NaN  256608
# 43904             http://www.thelastmanonearthmovie.com/  328212
# 43963                                                NaN  362844
# 43993                                                NaN   37851
# 44002                                                NaN   14210
# 44094                                                NaN   73144
# 44103                                                NaN   63838
# 44173                                                NaN  107170
# 44209                                                NaN   44592
# 44251                                                NaN  162042
# 44271                                                NaN  316154
# 44301                                                NaN  341689
# 44344  https://www.ismovies.net/movie/the-gracefield-...  327253
# 44345                                                NaN  154727
# 44444                                                NaN   82495
# 44559                                                NaN  301876
# 44582                                                NaN  436994
# 44624                                                NaN  406990
# 44754                                                NaN  204611
# 44893                                                NaN   32534
# 44894                                                NaN   18040
# 44969        https://www.youtube.com/watch?v=Tm0V24IEHao  463800
# 45053                                                NaN  419786
# 45116                                                NaN   10840
# 45300                                                NaN   58133
# 45430                                                NaN  222872
#
#       original_language                                           overview  \
# 475                  en  A wealthy entrepreneur secretly creates a them...
# 1180                 en  Wallace and Gromit have run out of cheese and ...
# 1322                 en  When a destructive space entity is spotted app...
# 1324                 en  Capt. Kirk and his crew must deal with Mr. Spo...
# 1462                 en  The third film in a trilogy by writer-director...
# 1613                 en                                 No overview found.
# 1684                 en  The OSSA discovers a spacecraft thought to be ...
# 1917                 en  Steve Clark (James Marsden) is a newcomer in t...
# 1996                 en  As Kevin Flynn searches for proof that he inve...
# 2010                 en  When a comet passes close to the earth, machin...
# 2162                 en  In a post-apocalyptic world where the Russians...
# 2250                 ja  Japan is thrown into a panic after several shi...
# 2342                 en  When Seth Brundle makes a huge scientific and ...
# 2441                 en  Six children are found spread through out the ...
# 2543                 en  The CIA sends playboy Mike Trent to Alaska wit...
# 2546                 en  Author &amp; amateur astronomer John Putnam an...
# 2547                 en  The residents of a small town are excited when...
# 2548                 en  A Giant Octopus, whose feeding habits have bee...
# 2586                 en  Legless Southern inventor Dr. Arliss Loveless ...
# 2902                 en  A dedicated student at a medical college and h...
# 3073                 en  Set in the 22nd century, when a battered salva...
# 3086                 en  Nazi hunter Ezra Lieberman discovers a siniste...
# 3236                 en  When contact is lost with the crew of the firs...
# 3351                 en  After an encounter with UFOs, a line worker fe...
# 3516                 en  During the transportation of a Space Shuttle a...
# 3610                 en  A government agent is determined to come to hi...
# 3710                 en  Dr. Bill Cortner (Jason Evers) and his fiancée...
# 3739                 en  A psychotherapist journeys inside a comatose s...
# 3740                 ja  Godzilla saves Tokyo from a flying saucer that...
# 3856                 en  Astronauts search for solutions to save a dyin...
# ...                 ...                                                ...
# 43439                sv  Three students at a Swedish university make a ...
# 43450                en  A long forgotten ancient spacecraft discovered...
# 43455                en  An astronaut (Anthony Dexter) and crew land on...
# 43480                tr                                                NaN
# 43665                pl  Young couple living in the old house suddenly ...
# 43904                en  The Last Man On Earth is about two teenagers e...
# 43963                en                                                NaN
# 43993                ru  The continuation of the adventures of the hero...
# 44002                en                                                NaN
# 44094                en  A woman wakes up in a room with no memory of w...
# 44103                ru                                                NaN
# 44173                en  Ghost Recon: Alpha sees a team led by Ghost Le...
# 44209                en  It's Cesar Romero versus dinosaurs in this cla...
# 44251                en  Dimwitted, meaty guy foils criminals by turnin...
# 44271                en  In a desert wasteland in Texas, a muscled cann...
# 44301                en  A couple of British 1970s teen-aged boys, Enn ...
# 44344                en  On August 16, 2013, the Supreme Court mandated...
# 44345                ja  Based on a series of sci-fi novels, this serie...
# 44444                fr                                                NaN
# 44559                en                                                NaN
# 44582                ko  Dae-ho, an investigative journalist, seeks to ...
# 44624                en  In a world where families are limited to one c...
# 44754                en  On a typical fall evening in 1983, a young man...
# 44893                en  Dark shadows are cast over Bill's recovery, in...
# 44894                en  On March 13th, 1997 one of the largest UFO sig...
# 44969                en  Set during the Vietnam war, Firebase follows A...
# 45053                en  After Martha Jones parts company with the Doct...
# 45116                ja  This animated short by Miyazaki was created as...
# 45300                fr  La Possibilité d'une île is a 2008 film direct...
# 45430                en            Sci-fi thriller directed by Fred Gallo.
#
#       popularity                                        poster_path  \
# 475      8.86378  http://image.tmdb.org/t/p/w185//c414cDeQ9b6qLP...
# 1180      7.6173  http://image.tmdb.org/t/p/w185//jgQU84QuFQ4yof...
# 1322     8.27776  http://image.tmdb.org/t/p/w185//ys5Sgpc27mVo3H...
# 1324      12.308  http://image.tmdb.org/t/p/w185//kugwPq2E5Ikzrg...
# 1462     3.32449  http://image.tmdb.org/t/p/w185//t3IQ4YOwFG71M1...
# 1613    0.106499  http://image.tmdb.org/t/p/w185//4Abbxth4pOwiM2...
# 1684     7.12474  http://image.tmdb.org/t/p/w185//jrjzPjKnpJq99G...
# 1917     11.0548  http://image.tmdb.org/t/p/w185//8eRU4c5vsCrUT5...
# 1996      16.574  http://image.tmdb.org/t/p/w185//cTF8lpXvAwT1SL...
# 2010     6.61408  http://image.tmdb.org/t/p/w185//lgNXAQ1TlKEKzs...
# 2162     2.74099  http://image.tmdb.org/t/p/w185//8uTLYIaRBx1xZ1...
# 2250     13.1533  http://image.tmdb.org/t/p/w185//1MJcpTpeSh2RtR...
# 2342     13.5346  http://image.tmdb.org/t/p/w185//q49tjSe3O152t9...
# 2441      2.4163  http://image.tmdb.org/t/p/w185//fjIiCQJRIpJTGU...
# 2543    0.432126  http://image.tmdb.org/t/p/w185//fk2sVtesehLfp0...
# 2546     7.74911  http://image.tmdb.org/t/p/w185//hIYZaXip6eZDN9...
# 2547      5.6094  http://image.tmdb.org/t/p/w185//kCbFRaaDob0bmR...
# 2548     2.91707  http://image.tmdb.org/t/p/w185//wTFPbEWY1zQxU9...
# 2586      9.8876  http://image.tmdb.org/t/p/w185//ouhNr6KsjOBSPx...
# 2902     9.86724  http://image.tmdb.org/t/p/w185//hJnP2O0uTuh8Hs...
# 3073     5.49662  http://image.tmdb.org/t/p/w185//xSw9HKPKwFx63p...
# 3086      5.9233  http://image.tmdb.org/t/p/w185//9fwAXB7cal1K0L...
# 3236     9.02111  http://image.tmdb.org/t/p/w185//eco5chujn3Mt7H...
# 3351     10.6104  http://image.tmdb.org/t/p/w185//mABOVIUl5lB0WF...
# 3516     10.5763  http://image.tmdb.org/t/p/w185//pz2r25q3NzNTDG...
# 3610      11.844  http://image.tmdb.org/t/p/w185//u23CCG87bWtpnP...
# 3710     2.13143  http://image.tmdb.org/t/p/w185//lEmcF0P87S1sGK...
# 3739     13.2349  http://image.tmdb.org/t/p/w185//tu2rPoVBhEp9fZ...
# 3740     2.80298  http://image.tmdb.org/t/p/w185//iFqf6rOnVdBGR3...
# 3856     8.53418  http://image.tmdb.org/t/p/w185//sMholOUc89LQhp...
# ...          ...                                                ...
# 43439   0.106215  http://image.tmdb.org/t/p/w185//cYYfFIjWTWBNHI...
# 43450   0.427982  http://image.tmdb.org/t/p/w185//piTPKYtaZjwnCR...
# 43455   0.957614  http://image.tmdb.org/t/p/w185//cITwrutRePXugZ...
# 43480   0.219218  http://image.tmdb.org/t/p/w185//30Lw7lbSXwm9NU...
# 43665   0.094228  http://image.tmdb.org/t/p/w185//6p2pvaO2hrvx8o...
# 43904   0.330445  http://image.tmdb.org/t/p/w185//AaOXG4XqmIkjpV...
# 43963   0.002603  http://image.tmdb.org/t/p/w185//pe2FQ7L96zkBaL...
# 43993   0.884241  http://image.tmdb.org/t/p/w185//vtiqEEw0GH5OiK...
# 44002   0.782646  http://image.tmdb.org/t/p/w185//gxuXvSu2JkmP6G...
# 44094   3.444679  http://image.tmdb.org/t/p/w185//e8bRqOm0mjP2WQ...
# 44103   0.414793  http://image.tmdb.org/t/p/w185//be78nAT5VLN2ET...
# 44173   3.036216  http://image.tmdb.org/t/p/w185//jfzhuHGAC9IM8Y...
# 44209   1.027404  http://image.tmdb.org/t/p/w185//lO34an5IGKUT3q...
# 44251   0.038963  http://image.tmdb.org/t/p/w185//v72XVa62vnXyac...
# 44271    78.8072  http://image.tmdb.org/t/p/w185//7o14VaMphEIzPw...
# 44301   2.068008  http://image.tmdb.org/t/p/w185//tyCt5dQ2yhfEtW...
# 44344   4.184306  http://image.tmdb.org/t/p/w185//lWZsV3dJfpWlEQ...
# 44345   0.398224  http://image.tmdb.org/t/p/w185//6P9jbdQY9CJiH9...
# 44444   0.759754  http://image.tmdb.org/t/p/w185//cSqDV2lkJt3a7x...
# 44559   0.039591  http://image.tmdb.org/t/p/w185//kBTaeHeOmRn1WP...
# 44582   1.748838  http://image.tmdb.org/t/p/w185//kFNCZo3ME1q83x...
# 44624  60.581223  http://image.tmdb.org/t/p/w185//o6EsOqITcSzcdw...
# 44754    0.00022  http://image.tmdb.org/t/p/w185//67PsLwiDS2K9y1...
# 44893   0.472132  http://image.tmdb.org/t/p/w185//5V02nhJlXdcTUj...
# 44894   2.426373  http://image.tmdb.org/t/p/w185//cMaSJn4ZyeOjmS...
# 44969   2.129137  http://image.tmdb.org/t/p/w185//e6qVOjp3QKHrA7...
# 45053   0.434906  http://image.tmdb.org/t/p/w185//d8VUkX1NGIZMK7...
# 45116   1.674261  http://image.tmdb.org/t/p/w185//rzeek3zGw9il7f...
# 45300   0.402427  http://image.tmdb.org/t/p/w185//1kFhV7ZxW54uY3...
# 45430   1.188052  http://image.tmdb.org/t/p/w185//kYRubwfzgCk9IM...
#
#                                     production_companies     ...      \
# 475    [{'name': 'Universal Pictures', 'id': 33}, {'n...     ...
# 1180         [{'name': 'Aardman Animations', 'id': 297}]     ...
# 1322           [{'name': 'Paramount Pictures', 'id': 4}]     ...
# 1324           [{'name': 'Paramount Pictures', 'id': 4}]     ...
# 1462   [{'name': 'Desperate Pictures', 'id': 1474}, {...     ...
# 1613                                                  []     ...
# 1684   [{'name': 'Punch Productions', 'id': 2154}, {'...     ...
# 1917   [{'name': 'Village Roadshow Pictures', 'id': 7...     ...
# 1996   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...     ...
# 2010   [{'name': 'De Laurentiis Entertainment Group (...     ...
# 2162                 [{'name': 'HSX Films', 'id': 4714}]     ...
# 2250   [{'name': 'Toho Film (Eiga) Co. Ltd.', 'id': 6...     ...
# 2342   [{'name': 'SLM Production Group', 'id': 396}, ...     ...
# 2441   [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8...     ...
# 2543     [{'name': 'Colonial Productions', 'id': 57825}]     ...
# 2546   [{'name': 'Universal International Pictures (U...     ...
# 2547           [{'name': 'Paramount Pictures', 'id': 4}]     ...
# 2548   [{'name': 'Columbia Pictures', 'id': 5}, {'nam...     ...
# 2586   [{'name': 'Todman, Simon, LeMasters Production...     ...
# 2902           [{'name': 'Empire Pictures', 'id': 1212}]     ...
# 3073   [{'name': 'United Artists', 'id': 60}, {'name'...     ...
# 3086   [{'name': 'Producers Circle', 'id': 734}, {'na...     ...
# 3236   [{'name': 'Spyglass Entertainment', 'id': 158}...     ...
# 3351   [{'name': 'Columbia Pictures Corporation', 'id...     ...
# 3516   [{'name': 'United Artists', 'id': 60}, {'name'...     ...
# 3610   [{'name': 'Twentieth Century Fox Film Corporat...     ...
# 3710   [{'name': 'Rex Carlton Productions', 'id': 123...     ...
# 3739   [{'name': 'New Line Cinema', 'id': 12}, {'name...     ...
# 3740   [{'name': 'Toho Film (Eiga) Co. Ltd.', 'id': 6...     ...
# 3856   [{'name': 'Village Roadshow Pictures', 'id': 7...     ...
# ...                                                  ...     ...
# 43439                                                 []     ...
# 43450         [{'name': 'MT2 Productions', 'id': 86979}]     ...
# 43455         [{'name': 'Criterion Films', 'id': 13731}]     ...
# 43480                                                 []     ...
# 43665  [{'name': 'Studio Filmowe Zebra', 'id': 58225}...     ...
# 43904         [{'name': 'Visionary Films', 'id': 47783}]     ...
# 43963                                                 []     ...
# 43993                                                 []     ...
# 44002  [{'name': 'Camera', 'id': 19615}, {'name': 'L&...     ...
# 44094                                                 []     ...
# 44103         [{'name': 'Kinokompaniya CTB', 'id': 886}]     ...
# 44173                  [{'name': 'Ubisoft', 'id': 4615}]     ...
# 44209  [{'name': 'Sigmund Neufeld Productions', 'id':...     ...
# 44251                                                 []     ...
# 44271  [{'name': 'Annapurna Pictures', 'id': 13184}, ...     ...
# 44301  [{'name': 'HanWay Films', 'id': 2395}, {'name'...     ...
# 44344                                                 []     ...
# 44345            [{'name': 'Tokuma Shoten', 'id': 1779}]     ...
# 44444                                                 []     ...
# 44559                                                 []     ...
# 44582                [{'name': '(주)로드픽쳐스', 'id': 87426}]     ...
# 44624  [{'name': 'Vendome Pictures', 'id': 7460}, {'n...     ...
# 44754                                                 []     ...
# 44893            [{'name': 'Bitter Films', 'id': 63349}]     ...
# 44894  [{'name': 'Ringleader Studios', 'id': 3338}, {...     ...
# 44969             [{'name': 'Oats Studio', 'id': 91393}]     ...
# 45053                                                 []     ...
# 45116           [{'name': 'Studio Ghibli', 'id': 10342}]     ...
# 45300          [{'name': 'Mandarin Films', 'id': 12096}]     ...
# 45430       [{'name': 'The Pacific Trust', 'id': 30376}]     ...
#
#                                         spoken_languages           status  \
# 475    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 1180            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1322            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1324            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1462            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1613            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1684            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1917            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1996            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2010            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2162            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2250                [{'iso_639_1': 'ja', 'name': '日本語'}]         Released
# 2342            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2441   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 2543            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2546            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2547   [{'iso_639_1': 'cs', 'name': 'Český'}, {'iso_6...         Released
# 2548            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2586            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2902   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 3073            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3086            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3236            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3351   [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...         Released
# 3516   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 3610            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3710            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3739            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3740                [{'iso_639_1': 'ja', 'name': '日本語'}]         Released
# 3856            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# ...                                                  ...              ...
# 43439                                                 []         Released
# 43450           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43455           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43480            [{'iso_639_1': 'tr', 'name': 'Türkçe'}]         Released
# 43665  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...         Released
# 43904           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43963           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43993           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 44002           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44094           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44103           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 44173           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44209           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44251           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44271           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44301           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44344           [{'iso_639_1': 'en', 'name': 'English'}]  Post Production
# 44345               [{'iso_639_1': 'ja', 'name': '日本語'}]         Released
# 44444          [{'iso_639_1': 'fr', 'name': 'Français'}]         Released
# 44559  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 44582           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]         Released
# 44624           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44754           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44893                                                 []         Released
# 44894           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44969  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 45053           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 45116       [{'iso_639_1': 'xx', 'name': 'No Language'}]         Released
# 45300          [{'iso_639_1': 'fr', 'name': 'Français'}]         Released
# 45430                                                 []         Released
#
#                                                  tagline  \
# 475         An adventure 65 million years in the making.
# 1180                                                 NaN
# 1322              The human adventure is just beginning.
# 1324   Adventure and imagination will meet at the fin...
# 1462                           Let the love feast begin.
# 1613                                       Run Baby Run!
# 1684   A thousand feet beneath the sea, the blackest ...
# 1917   In Cradle Bay it doesn’t matter if you’re not ...
# 1996   A world inside the computer where man has neve...
# 2010   Stephen King's masterpiece of terror directed ...
# 2162                             Vegas Needs a New King.
# 2250                                         It's Alive!
# 2342                          Be afraid. Be very afraid.
# 2441                    Beware the eyes that paralyze!!!
# 2543                                                 NaN
# 2546                   Fantastic sights leap out at you!
# 2547   Amazing! terrifying! The most savage spectacle...
# 2548                        IT CRUSHES! KILLS! DESTROYS!
# 2586                              It's a whole new west.
# 2902   Herbert West has a good head on his shoulders....
# 3073   In the farthest reaches of space, something ha...
# 3086                          If they survive...will we?
# 3236                                  Let There Be Life.
# 3351                                   We are not alone.
# 3516                     Outer space now belongs to 007.
# 3610               An experience in terror and suspense.
# 3710   Alive... without a body... fed by an unspeakab...
# 3739                          Enter The Mind Of A Killer
# 3740                               Get ready to crumble.
# 3856   Not A Sound. Not A Warning. Not A Chance. Not ...
# ...                                                  ...
# 43439                                                NaN
# 43450                                                NaN
# 43455  SEE - the CREATURE OF HORROR who RAVISHED A PL...
# 43480                                                NaN
# 43665                                                NaN
# 43904                                   Alone. Together.
# 43963                                                NaN
# 43993                                                NaN
# 44002                                                NaN
# 44094                                                NaN
# 44103                                                NaN
# 44173                                                NaN
# 44209               Monsters in a land that time forgot!
# 44251         An unforgettable excursion into adventure.
# 44271                                                NaN
# 44301                  Some girls are out of this world.
# 44344                                                NaN
# 44345                                                NaN
# 44444                                                NaN
# 44559                                                NaN
# 44582                                                NaN
# 44624                       Seven sisters. One identity.
# 44754                                                NaN
# 44893                                                NaN
# 44894                                                NaN
# 44969                                                NaN
# 45053                                                NaN
# 45116                                                NaN
# 45300                                                NaN
# 45430                                                NaN
#
#                                                    title  video vote_average  \
# 475                                        Jurassic Park  False          7.6
# 1180                                     A Grand Day Out  False          7.4
# 1322                       Star Trek: The Motion Picture  False          6.2
# 1324                     Star Trek V: The Final Frontier  False          5.6
# 1462                                             Nowhere  False          6.3
# 1613                                        Alien Escape  False          4.5
# 1684                                              Sphere  False          5.8
# 1917                                 Disturbing Behavior  False          5.5
# 1996                                                Tron  False          6.6
# 2010                                   Maximum Overdrive  False          5.5
# 2162                                  Six-String Samurai  False          5.8
# 2250                                            Godzilla  False          6.9
# 2342                                             The Fly  False          7.1
# 2441                              Children of the Damned  False          5.9
# 2543                                   The Flying Saucer  False          2.7
# 2546                            It Came from Outer Space  False          6.2
# 2547                               The War of the Worlds  False          6.8
# 2548                        It Came from Beneath the Sea  False          5.4
# 2586                                      Wild Wild West  False          5.1
# 2902                                         Re-Animator  False          7.0
# 3073                                           Supernova  False          4.9
# 3086                                The Boys from Brazil  False          6.6
# 3236                                     Mission to Mars  False          5.7
# 3351                  Close Encounters of the Third Kind  False          7.2
# 3516                                           Moonraker  False          5.9
# 3610                                            The Fury  False          6.2
# 3710                         The Brain That Wouldn't Die  False          4.4
# 3739                                            The Cell  False          6.0
# 3740                                       Godzilla 2000  False          5.9
# 3856                                          Red Planet  False          5.4
# ...                                                  ...    ...          ...
# 43439                                             Origin  False          6.0
# 43450                             Moontrap: Target Earth  False          4.0
# 43455                        Fire Maidens of Outer Space  False          2.2
# 43480                                          Japon İşi  False          6.3
# 43665                                            Embassy  False          4.5
# 43904                              The Last Man on Earth  False          7.0
# 43963                                           Survivor  False          0.0
# 43993               Hooked on the Game 2. The Next Level  False          5.1
# 44002                                Nightmare City 2035  False          4.5
# 44094                                  Portal: No Escape  False          7.0
# 44103                                        Mechenosets  False          5.6
# 44173                                 Ghost Recon: Alpha  False          7.5
# 44209                                     Lost Continent  False          2.0
# 44251                                  Riding with Death  False          2.4
# 44271                                      The Bad Batch  False          5.3
# 44301                    How to Talk to Girls at Parties  False          0.0
# 44344                            The Gracefield Incident  False          4.7
# 44345  Legend of the Galactic Heroes: Overture to a N...  False          7.2
# 44444                                              Gamer  False          3.2
# 44559                                   30 Years to Life  False          5.0
# 44582                                        Lucid Dream  False          6.8
# 44624                            What Happened to Monday  False          7.3
# 44754                                      UFO Abduction  False          6.7
# 44893                               I Am So Proud of You  False          8.3
# 44894                                        Night Skies  False          4.5
# 44969                                           Firebase  False          7.3
# 45053                             Doctor Who: Time Crash  False          8.0
# 45116                                       On Your Mark  False          7.3
# 45300                           Possibility of an Island  False          4.8
# 45430                                       Starquest II  False          2.0
#
#       vote_count  year     return  sub_genres
# 475         4956  1993  14.604762
# 1180         199  1990        NaN
# 1322         541  1979   3.971429
# 1324         384  1989   2.340000
# 1462          27  1997        NaN
# 1613           2  1996        NaN
# 1684         483  1998   0.174667
# 1917         104  1998   1.167158
# 1996         717  1982   1.941176
# 2010         170  1986   0.743366
# 2162          36  1998   0.062247
# 2250         194  1954        NaN
# 2342        1038  1986   4.041944
# 2441          24  1964        NaN
# 2543           7  1950        NaN
# 2546          52  1953        NaN
# 2547         172  1953   1.000000
# 2548          20  1955        NaN
# 2586        1042  1999   1.306498
# 2902         263  1985   2.248238
# 3073         109  2000   0.164756
# 3086         102  1978        NaN
# 3236         374  2000   0.676385
# 3351        1122  1977  15.189432
# 3516         551  1979   6.185532
# 3610          73  1978   4.363636
# 3710          34  1962        NaN
# 3739         442  2000   3.156238
# 3740          44  1999  10.037390
# 3856         271  2000   0.418300
# ...          ...   ...        ...         ...
# 43439          1  2016        NaN
# 43450          8  2017        NaN
# 43455          7  1956        NaN
# 43480          2  1987        NaN
# 43665          2  2013        NaN
# 43904          1  2014        NaN
# 43963          0  1999        NaN
# 43993         14  2010   0.655531
# 44002          6  2007        NaN
# 44094         38  2011        NaN
# 44103          7  2006   0.783946
# 44173         43  2012        NaN
# 44209          5  1951        NaN
# 44251          5  1976        NaN
# 44271        160  2017        NaN
# 44301         10  2017        NaN
# 44344         26  2017        NaN
# 44345          5  1993        NaN
# 44444          5  2001        NaN
# 44559          1  1998        NaN
# 44582         27  2017        NaN
# 44624        598  2017        NaN
# 44754          6  1989        NaN
# 44893         12  2008        NaN
# 44894         12  2007        NaN
# 44969         28  2017        NaN
# 45053         12  2007        NaN
# 45116         28  1995        NaN
# 45300          3  2008        NaN
# 45430          1  1996        NaN
#
# [378 rows x 24 columns]

# %%
df_movies_sff.to_csv('movies_metadata_scififantasy_v2.csv',sep=',')
