# %%
import pandas as pd
import numpy as np

# %%
df_movies_metadata = pd.read_csv('movies_metadata.csv')
# Out:
# /usr/local/Cellar/python/2.7.12/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df_movies_metadata.columns)
# Out:
# Index([u'adult', u'belongs_to_collection', u'budget', u'genres', u'homepage',
#        u'id', u'imdb_id', u'original_language', u'original_title', u'overview',
#        u'popularity', u'poster_path', u'production_companies',
#        u'production_countries', u'release_date', u'revenue', u'runtime',
#        u'spoken_languages', u'status', u'tagline', u'title', u'video',
#        u'vote_average', u'vote_count'],
#       dtype='object')

# %%
df_movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview    ...     release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1  When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2  A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4  Just when George Banks has recovered from his ...    ...       1995-02-10
#
#      revenue runtime                                   spoken_languages  \
# 0  373554033      81           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249     104  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0     101           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156     127           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911     106           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7       5415
# 1                      Jumanji  False          6.9       2413
# 2             Grumpier Old Men  False          6.5         92
# 3            Waiting to Exhale  False          6.1         34
# 4  Father of the Bride Part II  False          5.7        173
#
# [5 rows x 24 columns]

# %%
df_movies_metadata.shape
# Out:
# (45466, 24)

# %%
df_movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.7+ MB

# %%
# Remove features that are not useful
df_movies_metadata = df_movies_metadata.drop(['imdb_id'], axis=1)

# %%
df_movies_metadata[df_movies_metadata['original_title'] != df_movies_metadata['title']][['title', 'original_title']].head()
# Out:
#                         title                    original_title
# 28  The City of Lost Children        La Cité des Enfants Perdus
# 29             Shanghai Triad                         摇啊摇，摇到外婆桥
# 32           Wings of Courage  Guillaumet, les ailes du courage
# 57                The Postman                        Il postino
# 58           The Confessional                  Le confessionnal

# %%
df_movies_metadata = df_movies_metadata.drop('original_title', axis=1)

# %%
df_movies_metadata['revenue'] = df_movies_metadata['revenue'].replace(0, np.nan)

# %%
df_movies_metadata['budget'] = pd.to_numeric(df_movies_metadata['budget'], errors='coerce')
df_movies_metadata['budget'] = df_movies_metadata['budget'].replace(0, np.nan)
df_movies_metadata[df_movies_metadata['budget'].isnull()].shape
# Out:
# (36576, 22)

# %%
# Drop Adult movies
df_movies_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  - Written by Ørnås                                                                                                                   1
# Name: adult, dtype: int64

# %%
df_movies_metadata = df_movies_metadata.drop('adult', axis=1)

# %%
base_poster_url = 'http://image.tmdb.org/t/p/w185/'
df_movies_metadata['poster_path'] = base_poster_url + df_movies_metadata['poster_path']

# %%
# create the year feature
df_movies_metadata['year'] = pd.to_datetime(df_movies_metadata['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
# create the return feature
df_movies_metadata['return'] = df_movies_metadata['revenue'] / df_movies_metadata['budget']
df_movies_metadata[df_movies_metadata['return'].isnull()].shape
# Let's explore our dataset again
df_movies_metadata.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...       NaN
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...       NaN
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id original_language  \
# 0  http://toystory.disney.com/toy-story    862                en
# 1                                   NaN   8844                en
# 2                                   NaN  15602                en
# 3                                   NaN  31357                en
# 4                                   NaN  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  Just when George Banks has recovered from his ...    8.38752
#
#                                          poster_path  \
# 0  http://image.tmdb.org/t/p/w185//rhIRbceoE9lR4v...
# 1  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 2  http://image.tmdb.org/t/p/w185//6ksm1sjKMFLbO7...
# 3  http://image.tmdb.org/t/p/w185//16XOMpEaLWkrcP...
# 4  http://image.tmdb.org/t/p/w185//e64sOI48hQXyru...
#
#                                 production_companies    ...     runtime  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]    ...          81
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...         104
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    ...         101
# 3  [{'name': 'Twentieth Century Fox Film Corporat...    ...         127
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...    ...         106
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year     return
# 0                    Toy Story  False          7.7       5415  1995  12.451801
# 1                      Jumanji  False          6.9       2413  1995   4.043035
# 2             Grumpier Old Men  False          6.5         92  1995        NaN
# 3            Waiting to Exhale  False          6.1         34  1995   5.090760
# 4  Father of the Bride Part II  False          5.7        173  1995        NaN
#
# [5 rows x 23 columns]

# %%
# Filter only on Science Fiction and Fantasy
df_movies_sff = df_movies_metadata[df_movies_metadata['genres'].str.contains("Science Fiction|Fantasy")]
df_movies_sff.shape
# Out:
# (4844, 23)

# %%
# Let's explore our dataset again
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN  65000000
# 23                                                NaN       NaN
# 28                                                NaN  18000000
# 31                                                NaN  29500000
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies    ...    runtime  \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...        104
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...    ...        111
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...    ...        108
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...        129
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...         89
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year    return
# 1                     Jumanji  False          6.9       2413  1995  4.043035
# 23                     Powder  False          6.3        143  1995       NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.096589
# 31             Twelve Monkeys  False          7.4       2470  1995  5.723390
# 33                       Babe  False          6.0        756  1995  8.471164
#
# [5 rows x 23 columns]

# %%
# Sub-genre List
# - alien (Alien)
# - monster (Monster)
# - space (Space Opera)
# - robot (AI/Robot)
# - time_travel (Time Travel)
# - super (Superheroes)
# - dystopian (Dystopian)
# - fantasy (Fantasy)
# - techno (Technology Thriller)
# Approach: Create new column called sub_genres
# if overview column contains word, append that word + '/' to the cell in sub_genres

# Create new column called sub_genres
df_movies_sff['sub_genres'] = ''
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def search(df, *words):  #1
    """
    Return a sub-DataFrame of those rows whose Name column match all the words.
    """
    return df[np.logical_or.reduce([df.select_dtypes(include=[object]).stack().\
                                    str.contains(word, case=False, na=False).unstack().any(1) for word in words])]   # 2

# %%
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN  65000000
# 23                                                NaN       NaN
# 28                                                NaN  18000000
# 31                                                NaN  29500000
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies     ...      \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...     ...
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...     ...
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...     ...
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...     ...
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...     ...
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year    return  \
# 1                     Jumanji  False          6.9       2413  1995  4.043035
# 23                     Powder  False          6.3        143  1995       NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.096589
# 31             Twelve Monkeys  False          7.4       2470  1995  5.723390
# 33                       Babe  False          6.0        756  1995  8.471164
#
#     sub_genres
# 1
# 23
# 28
# 31
# 33
#
# [5 rows x 24 columns]

# %%
search(df_movies_sff, 'saucer', 'alien', 'life', 'human', 'extraterrestrial', 'ufo', 'parasite'\
                        'meteorite', 'meteor').index
# Out:
# Int64Index([   23,    43,    59,    75,   155,   157,   169,   193,   198,
#               224,
#             ...
#             45191, 45203, 45337, 45346, 45353, 45356, 45375, 45429, 45444,
#             45445],
#            dtype='int64', length=1505)

# %%
df_movies_sff.loc[search(df_movies_sff, 'saucer', 'alien', 'life', 'human', 'extraterrestrial', 'ufo', 'parasite'\
                        'meteorite', 'meteor').index, 'sub_genres'] = 'alien/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'luke', 'star', 'spaceship', 'battle', 'interstellar', 'planet', 'enterprise', 'skywalker', 'darth', 'droid'\
                        'earth', 'spock', 'kirk', 'space', 'capt', 'moon', 'spacecraft', 'crew', 'comet', 'mars').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'space/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'cop', 'ai', 'cyborg', 'terminator', 'army', 'android', 'weapon', 'robot', 'intelligence', 'machine').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'robot/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'travel', 'time', 'back', 'frozen').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'time_travel/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'marvel', 'superman', 'superpower', 'super').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'super/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'virus', 'future', 'nuclear', 'city', 'epidemic', 'prison', 'dark', 'murder', 'evil', 'violence', 'experiment'\
                        'totalitarian', 'society', 'post-apocalyptic', 'dystopian', 'experiments').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'dystopian/'

# %%
df_movies_sff.loc[df_movies_sff['genres'].str.contains("Fantasy", case='False', na=False), 'sub_genres'] = df_movies_sff['sub_genres'].astype(str) + 'fantasy/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'frankenstein', 'vampire', 'werewolf', 'shark', 'spider', 'zombie', 'blob', 'creature', 'troll', 'gypsy', 'ape'\
                        'dinosaur', 'jurrasic', 'scientist', 'swamp', 'dinosaurs', 'monster', 'octopus', 'godzilla').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'monster/'

# %%
df_movies_sff.loc[search(df_movies_sff, 'computer', 'cyber', 'matrix', 'chip', 'network', 'serum', 'data', 'virtual', 'reality', 'laser', 'video', 'game'\
                        'player', 'tech').index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'techno/'

# %%
df_movies_sff['sub_genres'].value_counts()
# Out:
# robot/fantasy/                                                   242
# fantasy/                                                         220
# robot/time_travel/fantasy/                                       147
# robot/                                                           132
#                                                                  114
# time_travel/fantasy/                                             105
# robot/time_travel/dystopian/fantasy/                              91
# robot/dystopian/                                                  90
# robot/dystopian/fantasy/                                          85
# space/robot/fantasy/                                              84
# robot/time_travel/                                                81
# space/robot/                                                      73
# alien/space/robot/                                                72
# alien/robot/fantasy/                                              71
# dystopian/fantasy/                                                68
# robot/time_travel/dystopian/                                      66
# alien/robot/                                                      65
# space/robot/time_travel/                                          64
# dystopian/                                                        59
# space/robot/time_travel/dystopian/fantasy/                        58
# space/robot/time_travel/fantasy/                                  56
# space/                                                            52
# space/robot/dystopian/                                            50
# alien/robot/time_travel/fantasy/                                  48
# alien/space/robot/time_travel/                                    48
# robot/monster/                                                    46
# alien/                                                            46
# alien/fantasy/                                                    46
# alien/robot/dystopian/                                            43
# alien/space/robot/dystopian/                                      40
#                                                                 ...
# super/fantasy/techno/                                              1
# time_travel/monster/techno/                                        1
# alien/space/super/dystopian/fantasy/                               1
# alien/space/robot/super/dystopian/techno/                          1
# space/robot/super/techno/                                          1
# alien/time_travel/fantasy/monster/techno/                          1
# space/robot/time_travel/super/dystopian/techno/                    1
# robot/super/techno/                                                1
# alien/space/dystopian/monster/techno/                              1
# alien/space/time_travel/super/fantasy/monster/                     1
# alien/space/robot/fantasy/techno/                                  1
# robot/time_travel/super/monster/                                   1
# alien/robot/super/fantasy/techno/                                  1
# robot/super/fantasy/techno/                                        1
# space/super/dystopian/fantasy/                                     1
# alien/super/dystopian/monster/techno/                              1
# space/time_travel/super/monster/                                   1
# space/robot/time_travel/fantasy/monster/techno/                    1
# space/robot/super/fantasy/monster/                                 1
# time_travel/dystopian/fantasy/monster/techno/                      1
# space/robot/time_travel/super/monster/                             1
# space/time_travel/dystopian/techno/                                1
# alien/space/robot/super/monster/techno/                            1
# space/monster/techno/                                              1
# alien/space/time_travel/super/dystopian/monster/                   1
# space/time_travel/dystopian/fantasy/monster/techno/                1
# alien/space/time_travel/dystopian/fantasy/monster/                 1
# space/time_travel/super/dystopian/                                 1
# alien/space/super/techno/                                          1
# alien/space/robot/time_travel/super/dystopian/fantasy/techno/      1
# Name: sub_genres, dtype: int64

# %%
# number of empty sub_genres remaining
(df_movies_sff['sub_genres'].values == '').sum()
# Out:
# 114

# %%
# we still need to do some work here... label the rest of the movies with sub_genres
df_movies_sff.loc[df_movies_sff['sub_genres'].values=='']
# Out:
#       belongs_to_collection    budget  \
# 3086                    NaN       NaN
# 3610                    NaN   5500000
# 3861                    NaN  82000000
# 4285                    NaN       NaN
# 4805                    NaN       NaN
# 4814                    NaN       NaN
# 4836                    NaN    750000
# 4856                    NaN   4500000
# 4939                    NaN       NaN
# 5692                    NaN       NaN
# 5961                    NaN       NaN
# 6758                    NaN       NaN
# 7208                    NaN  20000000
# 7250                    NaN       NaN
# 7460                    NaN   7500000
# 7631                    NaN    950000
# 8073                    NaN   7500000
# 8187                    NaN      7000
# 8212                    NaN       NaN
# 8295                    NaN       NaN
# 8687                    NaN       NaN
# 8865                    NaN       NaN
# 9409                    NaN       NaN
# 9421                    NaN       NaN
# 10531                   NaN       NaN
# 11324                   NaN       NaN
# 11584                   NaN       NaN
# 12297                   NaN       NaN
# 12364                   NaN     50000
# 13024                   NaN       NaN
# ...                     ...       ...
# 36384                   NaN       NaN
# 36413                   NaN       NaN
# 37145                   NaN       NaN
# 39197                   NaN   2004384
# 39235                   NaN       NaN
# 39602                   NaN       NaN
# 41334                   NaN       NaN
# 42059                   NaN       NaN
# 42428                   NaN       NaN
# 42509                   NaN       NaN
# 42595                   NaN       NaN
# 42998                   NaN        12
# 43060                   NaN       NaN
# 43079                   NaN       NaN
# 43226                   NaN       NaN
# 43353                   NaN   2800000
# 43439                   NaN       NaN
# 43480                   NaN       NaN
# 43665                   NaN       NaN
# 43904                   NaN       NaN
# 43963                   NaN       NaN
# 44094                   NaN       NaN
# 44103                   NaN   5000000
# 44173                   NaN       NaN
# 44251                   NaN       NaN
# 44271                   NaN   6000000
# 44301                   NaN       NaN
# 44344                   NaN       NaN
# 44624                   NaN       NaN
# 44969                   NaN       NaN
#
#                                                   genres  \
# 3086   [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...
# 3610   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 3861            [{'id': 878, 'name': 'Science Fiction'}]
# 4285            [{'id': 878, 'name': 'Science Fiction'}]
# 4805   [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 4814   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 4836   [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 4856   [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 4939   [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 5692   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 5961   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 6758   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 7208   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 7250   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 7460   [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 7631   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 8073   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 8187   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8212   [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 8295   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 8687   [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 8865   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 9409   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 9421   [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 10531  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 11324  [{'id': 12, 'name': 'Adventure'}, {'id': 27, '...
# 11584  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 12297  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 12364  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 13024  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...                                                  ...
# 36384  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 36413  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 37145  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 39197           [{'id': 878, 'name': 'Science Fiction'}]
# 39235  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 39602           [{'id': 878, 'name': 'Science Fiction'}]
# 41334  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 42059  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 42428  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 42509  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 42595  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 42998  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 43060  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 43079  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 43226  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
# 43353  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 43439  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 43480  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 43665  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 43904  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 43963  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 44094  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 44103  [{'id': 28, 'name': 'Action'}, {'id': 10749, '...
# 44173  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 44251  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 44271  [{'id': 53, 'name': 'Thriller'}, {'id': 10749,...
# 44301  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 44344  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 44624  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 44969  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
#
#                                                 homepage      id  \
# 3086                                                 NaN   16241
# 3610                                                 NaN   12611
# 3861                                                 NaN    8452
# 4285                                                 NaN   42780
# 4805                                                 NaN   33356
# 4814                                                 NaN   42218
# 4836                                                 NaN   31682
# 4856                                                 NaN   27150
# 4939                                                 NaN   41870
# 5692                                                 NaN   18993
# 5961                                                 NaN   27380
# 6758                                                 NaN   44591
# 7208                      http://www.eternalsunshine.com      38
# 7250                                                 NaN   68347
# 7460                      http://www.miramax.com/cypher/   10133
# 7631                                                 NaN   29146
# 8073                                                 NaN    2577
# 8187                          http://www.primermovie.com   14337
# 8212                                                 NaN   11099
# 8295                                                 NaN    2972
# 8687                                                 NaN  121923
# 8865                                                 NaN   41243
# 9409                                                 NaN   15990
# 9421                                                 NaN  100594
# 10531                                                NaN   38761
# 11324                                                NaN    3593
# 11584                                                NaN    3024
# 12297                                                NaN   45871
# 12364                                                NaN   13059
# 13024                                                NaN    2397
# ...                                                  ...     ...
# 36384                                                NaN    4289
# 36413                                                NaN   27941
# 37145                                                NaN  185354
# 39197                             http://brandnew-u.com/  343724
# 39235                                                NaN   89662
# 39602                                                NaN  257006
# 41334                                                NaN  387801
# 42059                                                NaN  345925
# 42428                                                NaN  437122
# 42509                                                NaN  416688
# 42595                                                NaN  438597
# 42998                                                NaN   25610
# 43060                           http://bokehthemovie.com  286538
# 43079                                                NaN  447758
# 43226                                                NaN  381449
# 43353                       http://phoenixforgotten.com/  443319
# 43439                                                NaN  425487
# 43480                                                NaN  236053
# 43665                                                NaN  256608
# 43904             http://www.thelastmanonearthmovie.com/  328212
# 43963                                                NaN  362844
# 44094                                                NaN   73144
# 44103                                                NaN   63838
# 44173                                                NaN  107170
# 44251                                                NaN  162042
# 44271                                                NaN  316154
# 44301                                                NaN  341689
# 44344  https://www.ismovies.net/movie/the-gracefield-...  327253
# 44624                                                NaN  406990
# 44969        https://www.youtube.com/watch?v=Tm0V24IEHao  463800
#
#       original_language                                           overview  \
# 3086                 en  Nazi hunter Ezra Lieberman discovers a siniste...
# 3610                 en  A government agent is determined to come to hi...
# 3861                 en  Futuristic action about a man who meets a clon...
# 4285                 en  "Genius" accidentally invents "goo" which caus...
# 4805                 en  The exploration of the effects of an unexpecte...
# 4814                 en  Sleazy scam artist Joan Collins tries to sell ...
# 4836                 en  When exposure to a combination of radiation an...
# 4856                 en  A Texas sheriff tries kung fu on an ax killer ...
# 4939                 en  Set in empty junkyards of Winnipeg, Sabu works...
# 5692                 en  During the US Civil War, Union POWs escape in ...
# 5961                 en  Megaforce is an elite multi-national military ...
# 6758                 en  Giant scorpions wreck havoc after being releas...
# 7208                 en  Joel Barish, heartbroken that his girlfriend u...
# 7250                 en  A growth hormone experiment gets out of hand, ...
# 7460                 en  An unsuspecting, disenchanted man finds himsel...
# 7631                 en  An experiment on a simpleton turns him into a ...
# 8073                 en  A futuristic 'Brief Encounter', a love story i...
# 8187                 en  Friends/fledgling entrepreneurs invent a devic...
# 8212                 en  Set in a world with memory implants, Robin Wil...
# 8295                 de  In the 16th century, the Jews of Prague face p...
# 8687                 en  A mysterious man John Kane (Sidney Poitier) wh...
# 8865                 en  With the help of student assistant Boris and s...
# 9409                 en  The Cathedral (Polish: Katedra) is a 2002 shor...
# 9421                 fi                                                NaN
# 10531                en     Giant mutant rabbits terrorize the southwest!!
# 11324                en  Four explorers are summoned to Peru by the bri...
# 11584                en                                 No overview found.
# 12297                cn  Triad boss Lung (Eddy Ko), who has just escape...
# 12364                en  A horror film told in three parts, from three ...
# 13024                en                                 No overview found.
# ...                 ...                                                ...
# 36384                en  After an African dinosaur ancestor of the croc...
# 36413                en                                                NaN
# 37145                pl  Film opens on December 18, 1999, just a few da...
# 39197                en  Identicals is a highly unconventional romantic...
# 39235                en  A stone-encrusted body is unearthed at Pompeii...
# 39602                it  An oceanographer diving in the Bermuda Triangl...
# 41334                es  Hypnotic, perturbing, and utterly enthralling,...
# 42059                en  A single mom tries to break free from a myster...
# 42428                en                      Sci-fi end of the world drama
# 42509                en  A family of three young sisters live out their...
# 42595                ru  Igor Grom, a skilled detective from St. Peters...
# 42998                en  The small town of Haven becomes a hot-bed of i...
# 43060                en  On a romantic getaway to Iceland, a young Amer...
# 43079                en  It's 2067, the UK is vegan, but older generati...
# 43226                de  15 years ago the sea at the coast of Windholm ...
# 43353                en  20 years after three teenagers disappeared in ...
# 43439                sv  Three students at a Swedish university make a ...
# 43480                tr                                                NaN
# 43665                pl  Young couple living in the old house suddenly ...
# 43904                en  The Last Man On Earth is about two teenagers e...
# 43963                en                                                NaN
# 44094                en  A woman wakes up in a room with no memory of w...
# 44103                ru                                                NaN
# 44173                en  Ghost Recon: Alpha sees a team led by Ghost Le...
# 44251                en  Dimwitted, meaty guy foils criminals by turnin...
# 44271                en  In a desert wasteland in Texas, a muscled cann...
# 44301                en  A couple of British 1970s teen-aged boys, Enn ...
# 44344                en  On August 16, 2013, the Supreme Court mandated...
# 44624                en  In a world where families are limited to one c...
# 44969                en  Set during the Vietnam war, Firebase follows A...
#
#       popularity                                        poster_path  \
# 3086      5.9233  http://image.tmdb.org/t/p/w185//9fwAXB7cal1K0L...
# 3610      11.844  http://image.tmdb.org/t/p/w185//u23CCG87bWtpnP...
# 3861     8.41311  http://image.tmdb.org/t/p/w185//6pBUekwhnjW99V...
# 4285      0.6148  http://image.tmdb.org/t/p/w185//b77SRC0CMatdNN...
# 4805    0.866004  http://image.tmdb.org/t/p/w185//pJ5ftKZSO7by9G...
# 4814     3.24403  http://image.tmdb.org/t/p/w185//4ABMqLqGhu3ZXq...
# 4836     4.91023  http://image.tmdb.org/t/p/w185//pBBgIy2ncPgX5l...
# 4856     1.80861  http://image.tmdb.org/t/p/w185//AaUhLHvpyqrUVb...
# 4939    0.142296  http://image.tmdb.org/t/p/w185//ojfIXzEHNwjYEW...
# 5692     3.41931  http://image.tmdb.org/t/p/w185//gTHr5r7Ei5EZJj...
# 5961     1.35214  http://image.tmdb.org/t/p/w185//zpXDYcSR4y06fk...
# 6758    0.748812  http://image.tmdb.org/t/p/w185//dLqaQkI0EH4b8Z...
# 7208     12.9063  http://image.tmdb.org/t/p/w185//7y3eYvTsGjxPYD...
# 7250     1.15988  http://image.tmdb.org/t/p/w185//gVYpeXiLlRdx5h...
# 7460     7.34897  http://image.tmdb.org/t/p/w185//qzLRviv0UUCbmb...
# 7631     2.52616  http://image.tmdb.org/t/p/w185//4FVbPUkLohHAlM...
# 8073      6.1014  http://image.tmdb.org/t/p/w185//lOEo7iG0FV6mxp...
# 8187     7.15307  http://image.tmdb.org/t/p/w185//pYiAYDn3ltw9Fq...
# 8212     10.6068  http://image.tmdb.org/t/p/w185//8YPAz6LdWatGQW...
# 8295     1.52413  http://image.tmdb.org/t/p/w185//gzXqhVnd3Rfroa...
# 8687      0.9413  http://image.tmdb.org/t/p/w185//om5Efy8bxPdQHk...
# 8865     3.65014  http://image.tmdb.org/t/p/w185//yVpp427Ui7h6dP...
# 9409    0.903483  http://image.tmdb.org/t/p/w185//ticcTG4vVpuTWJ...
# 9421    0.203204  http://image.tmdb.org/t/p/w185//juhxfyFyQ7MXFL...
# 10531    1.17981  http://image.tmdb.org/t/p/w185//4ldYhM4swXlzBn...
# 11324   0.662919  http://image.tmdb.org/t/p/w185//5bUdwNdumc2cPz...
# 11584   0.424452  http://image.tmdb.org/t/p/w185//8byiRQ9kv2TUGn...
# 12297    1.53192  http://image.tmdb.org/t/p/w185//zmMjY2I8Aj8TG1...
# 12364    11.3297  http://image.tmdb.org/t/p/w185//OdJHcbCRcL03HK...
# 13024    1.68743  http://image.tmdb.org/t/p/w185//zU9hKyOjiR8NUp...
# ...          ...                                                ...
# 36384   4.638634  http://image.tmdb.org/t/p/w185//vvEfmC5Q8AOY1N...
# 36413   0.681163  http://image.tmdb.org/t/p/w185//bNgNvo7m7fikFq...
# 37145   0.242601  http://image.tmdb.org/t/p/w185//Dp4UIdT6V2egFX...
# 39197   1.090345  http://image.tmdb.org/t/p/w185//rtiKN28y3J1NVE...
# 39235   0.259001  http://image.tmdb.org/t/p/w185//spOquowSZMTt1J...
# 39602   0.000132  http://image.tmdb.org/t/p/w185//g9OkqOC7aTuOXD...
# 41334   1.414419  http://image.tmdb.org/t/p/w185//bpTNGIJkdYL8IJ...
# 42059   4.970237  http://image.tmdb.org/t/p/w185//ykqywWckRwyn7w...
# 42428   0.048262  http://image.tmdb.org/t/p/w185//7FHxlNOKHmtZwp...
# 42509   0.805734  http://image.tmdb.org/t/p/w185//p3zcRov2GIDwL3...
# 42595   0.874297  http://image.tmdb.org/t/p/w185//5gLABGKMMaUbod...
# 42998   9.156782  http://image.tmdb.org/t/p/w185//7r9Ym2elnrDg4I...
# 43060   6.165126  http://image.tmdb.org/t/p/w185//cedeEgSeKpsFZH...
# 43079   1.336149  http://image.tmdb.org/t/p/w185//8RQM8S8UJmVITc...
# 43226   0.452123  http://image.tmdb.org/t/p/w185//hPFwDTjlyHNot1...
# 43353  12.560942  http://image.tmdb.org/t/p/w185//8GJ9a0FgkCKIqK...
# 43439   0.106215  http://image.tmdb.org/t/p/w185//cYYfFIjWTWBNHI...
# 43480   0.219218  http://image.tmdb.org/t/p/w185//30Lw7lbSXwm9NU...
# 43665   0.094228  http://image.tmdb.org/t/p/w185//6p2pvaO2hrvx8o...
# 43904   0.330445  http://image.tmdb.org/t/p/w185//AaOXG4XqmIkjpV...
# 43963   0.002603  http://image.tmdb.org/t/p/w185//pe2FQ7L96zkBaL...
# 44094   3.444679  http://image.tmdb.org/t/p/w185//e8bRqOm0mjP2WQ...
# 44103   0.414793  http://image.tmdb.org/t/p/w185//be78nAT5VLN2ET...
# 44173   3.036216  http://image.tmdb.org/t/p/w185//jfzhuHGAC9IM8Y...
# 44251   0.038963  http://image.tmdb.org/t/p/w185//v72XVa62vnXyac...
# 44271    78.8072  http://image.tmdb.org/t/p/w185//7o14VaMphEIzPw...
# 44301   2.068008  http://image.tmdb.org/t/p/w185//tyCt5dQ2yhfEtW...
# 44344   4.184306  http://image.tmdb.org/t/p/w185//lWZsV3dJfpWlEQ...
# 44624  60.581223  http://image.tmdb.org/t/p/w185//o6EsOqITcSzcdw...
# 44969   2.129137  http://image.tmdb.org/t/p/w185//e6qVOjp3QKHrA7...
#
#                                     production_companies     ...      \
# 3086   [{'name': 'Producers Circle', 'id': 734}, {'na...     ...
# 3610   [{'name': 'Twentieth Century Fox Film Corporat...     ...
# 3861         [{'name': 'Phoenix Pictures', 'id': 11317}]     ...
# 4285   [{'name': 'Joseph E. Levine Productions', 'id'...     ...
# 4805   [{'name': 'British Film Institute (BFI)', 'id'...     ...
# 4814                 [{'name': 'Cinema 77', 'id': 1819}]     ...
# 4836   [{'name': 'Universal International Pictures (U...     ...
# 4856   [{'name': 'Columbia Pictures Corporation', 'id...     ...
# 4939                                                  []     ...
# 5692              [{'name': 'Ameran Films', 'id': 8488}]     ...
# 5961   [{'name': 'Golden Harvest Company', 'id': 2521...     ...
# 6758   [{'name': 'Amex Productions', 'id': 14233}, {'...     ...
# 7208   [{'name': 'Anonymous Content', 'id': 10039}, {...     ...
# 7250   [{'name': 'New Line Cinema', 'id': 12}, {'name...     ...
# 7460   [{'name': 'Miramax Films', 'id': 14}, {'name':...     ...
# 7631   [{'name': 'ABC Pictures', 'id': 634}, {'name':...     ...
# 8073                  [{'name': 'BBC Films', 'id': 288}]     ...
# 8187                  [{'name': 'Thinkfilm', 'id': 446}]     ...
# 8212            [{'name': 'Lions Gate Films', 'id': 35}]     ...
# 8295   [{'name': 'Projektions A-G Union (PAGU)', 'id'...     ...
# 8687   [{'name': 'Columbia Pictures Corporation', 'id...     ...
# 8865                                                  []     ...
# 9409                                                  []     ...
# 9421                                                  []     ...
# 10531  [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8...     ...
# 11324          [{'name': 'Paramount Pictures', 'id': 4}]     ...
# 11584                                                 []     ...
# 12297  [{'name': 'Milky Way Image Company', 'id': 5632}]     ...
# 12364                                                 []     ...
# 13024                                                 []     ...
# ...                                                  ...     ...
# 36384    [{'name': 'Concorde-New Horizons', 'id': 4688}]     ...
# 36413                                                 []     ...
# 37145          [{'name': 'Zespol Filmowy', 'id': 46567}]     ...
# 39197  [{'name': 'Hot Property Films', 'id': 4304}, {...     ...
# 39235  [{'name': 'Robert E. Kent Productions', 'id': ...     ...
# 39602                                                 []     ...
# 41334                                                 []     ...
# 42059  [{'name': 'Splendid Film', 'id': 8146}, {'name...     ...
# 42428                                                 []     ...
# 42509                                                 []     ...
# 42595          [{'name': 'BUBBLE Studios', 'id': 86050}]     ...
# 42998  [{'name': 'Konigsberg/Sanitsky Company', 'id':...     ...
# 43060  [{'name': 'Vintage Pictures', 'id': 35561}, {'...     ...
# 43079                                                 []     ...
# 43226  [{'name': 'Rundfunk Berlin-Brandenburg (RBB)',...     ...
# 43353  [{'name': 'Scott Free Productions', 'id': 1645...     ...
# 43439                                                 []     ...
# 43480                                                 []     ...
# 43665  [{'name': 'Studio Filmowe Zebra', 'id': 58225}...     ...
# 43904         [{'name': 'Visionary Films', 'id': 47783}]     ...
# 43963                                                 []     ...
# 44094                                                 []     ...
# 44103         [{'name': 'Kinokompaniya CTB', 'id': 886}]     ...
# 44173                  [{'name': 'Ubisoft', 'id': 4615}]     ...
# 44251                                                 []     ...
# 44271  [{'name': 'Annapurna Pictures', 'id': 13184}, ...     ...
# 44301  [{'name': 'HanWay Films', 'id': 2395}, {'name'...     ...
# 44344                                                 []     ...
# 44624  [{'name': 'Vendome Pictures', 'id': 7460}, {'n...     ...
# 44969             [{'name': 'Oats Studio', 'id': 91393}]     ...
#
#                                         spoken_languages           status  \
# 3086            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3610            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 3861            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4285            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4805            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4814            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4836            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4856   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 4939                                                  []         Released
# 5692            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 5961            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 6758            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 7208            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 7250            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 7460            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 7631            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 8073            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 8187            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 8212   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 8295        [{'iso_639_1': 'xx', 'name': 'No Language'}]         Released
# 8687            [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 8865            [{'iso_639_1': 'en', 'name': 'English'}]          Rumored
# 9409                                                  []         Released
# 9421              [{'iso_639_1': 'fi', 'name': 'suomi'}]         Released
# 10531           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 11324           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 11584           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 12297         [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}]         Released
# 12364           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 13024           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# ...                                                  ...              ...
# 36384           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 36413           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 37145            [{'iso_639_1': 'pl', 'name': 'Polski'}]         Released
# 39197           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 39235  [{'iso_639_1': 'it', 'name': 'Italiano'}, {'is...         Released
# 39602           [{'iso_639_1': 'es', 'name': 'Español'}]         Released
# 41334           [{'iso_639_1': 'es', 'name': 'Español'}]         Released
# 42059           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 42428                                                 []         Released
# 42509           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 42595           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 42998  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 43060           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43079           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43226           [{'iso_639_1': 'de', 'name': 'Deutsch'}]         Released
# 43353           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43439                                                 []         Released
# 43480            [{'iso_639_1': 'tr', 'name': 'Türkçe'}]         Released
# 43665  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...         Released
# 43904           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 43963           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44094           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44103           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 44173           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44251           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44271           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44301           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44344           [{'iso_639_1': 'en', 'name': 'English'}]  Post Production
# 44624           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 44969  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
#
#                                                  tagline  \
# 3086                          If they survive...will we?
# 3610               An experience in terror and suspense.
# 3861                       Are You Who You Think You Are
# 4285    All the kids grow 10 feet tall... and TAKE OVER!
# 4805                                                 NaN
# 4814                                     It's no picnic!
# 4836           A fascinating adventure into the unknown!
# 4856   He's an indestructible man fused with powers b...
# 4939                                                 NaN
# 5692   A world beyond imagination! Adventure beyond b...
# 5961                                     Deeds not Words
# 6758   Every horror you've seen on the screen grows p...
# 7208   You can erase someone from your mind. Getting ...
# 7250     It's their party... you can die if you want to.
# 7460                            Never forget who you are
# 7631   A love story that begins with an incredible ex...
# 8073   How do you solve a crime when the last thing y...
# 8187                  What happens if it actually works?
# 8212                     In the end, he sees everything.
# 8295                         The 1920 Horror Masterpiece
# 8687   Brother John just blew into town...and the tow...
# 8865   It's potentially dangerous, probably illegal a...
# 9409                                                 NaN
# 9421                                                 NaN
# 10531                    How many eyes does horror have?
# 11324                                                NaN
# 11584                                                NaN
# 12297                                                NaN
# 12364                                This is not a test.
# 13024                                                NaN
# ...                                                  ...
# 36384                                  It feeds on fear.
# 36413                                                NaN
# 37145                                                NaN
# 39197                None of us are as unique as we hope
# 39235  Entombed for eons - turned to stone - seeking ...
# 39602                                                NaN
# 41334                                                NaN
# 42059                                                NaN
# 42428                                 Unplanned Unwanted
# 42509                                                NaN
# 42595                                                NaN
# 42998  You can't run. You can't hide. You can only be...
# 43060                                                NaN
# 43079                                                NaN
# 43226                                                NaN
# 43353               Based on Shocking Untold True Events
# 43439                                                NaN
# 43480                                                NaN
# 43665                                                NaN
# 43904                                   Alone. Together.
# 43963                                                NaN
# 44094                                                NaN
# 44103                                                NaN
# 44173                                                NaN
# 44251         An unforgettable excursion into adventure.
# 44271                                                NaN
# 44301                  Some girls are out of this world.
# 44344                                                NaN
# 44624                       Seven sisters. One identity.
# 44969                                                NaN
#
#                                              title  video vote_average  \
# 3086                          The Boys from Brazil  False          6.6
# 3610                                      The Fury  False          6.2
# 3861                                   The 6th Day  False          5.7
# 4285                         Village of the Giants  False          3.3
# 4805                                     The Falls  False          8.0
# 4814                            Empire of the Ants  False          4.6
# 4836                  The Incredible Shrinking Man  False          7.3
# 4856                                   Silent Rage  False          5.0
# 4939                                     Hey Happy  False          3.4
# 5692                             Mysterious Island  False          6.2
# 5961                                     Megaforce  False          3.5
# 6758                            The Black Scorpion  False          5.1
# 7208         Eternal Sunshine of the Spotless Mind  False          7.9
# 7250                           Food of the Gods II  False          5.8
# 7460                                        Cypher  False          6.7
# 7631                                        Charly  False          6.6
# 8073                                       Code 46  False          6.2
# 8187                                        Primer  False          6.9
# 8212                                 The Final Cut  False          5.9
# 8295         The Golem: How He Came Into the World  False          7.0
# 8687                                  Brother John  False          6.2
# 8865                                       Creator  False          6.2
# 9409                                 The Cathedral  False          7.4
# 9421                              The Book of Fate  False          3.5
# 10531                           Night of the Lepus  False          4.9
# 11324                                  Dr. Cyclops  False          6.1
# 11584  The Strange Case of Dr. Jekyll and Mr. Hyde  False          0.0
# 12297                                  The Mission  False          6.7
# 12364                                   The Signal  False          5.9
# 13024                                      Fallout  False          0.0
# ...                                            ...    ...          ...
# 36384                                     Dinocroc  False          4.0
# 36413           Lockjaw: Rise of the Kulev Serpent  False          2.3
# 37145          The War of the Worlds: Next Century  False          6.5
# 39197                                   Identicals  False          4.1
# 39235                    Curse of the Faceless Man  False          5.3
# 39602                       Encounters in the Deep  False          0.0
# 41334                                  The Untamed  False          5.9
# 42059                                      Rupture  False          5.5
# 42428                                  Third Guest  False          0.0
# 42509                                    The Tribe  False          5.3
# 42595                                   Major Grom  False          6.6
# 42998                            The Tommyknockers  False          5.1
# 43060                                        Bokeh  False          5.1
# 43079                 Carnage: Swallowing the Past  False          8.3
# 43226                              We are the tide  False          5.0
# 43353                            Phoenix Forgotten  False          5.7
# 43439                                       Origin  False          6.0
# 43480                                    Japon İşi  False          6.3
# 43665                                      Embassy  False          4.5
# 43904                        The Last Man on Earth  False          7.0
# 43963                                     Survivor  False          0.0
# 44094                            Portal: No Escape  False          7.0
# 44103                                  Mechenosets  False          5.6
# 44173                           Ghost Recon: Alpha  False          7.5
# 44251                            Riding with Death  False          2.4
# 44271                                The Bad Batch  False          5.3
# 44301              How to Talk to Girls at Parties  False          0.0
# 44344                      The Gracefield Incident  False          4.7
# 44624                      What Happened to Monday  False          7.3
# 44969                                     Firebase  False          7.3
#
#       vote_count  year     return  sub_genres
# 3086         102  1978        NaN
# 3610          73  1978   4.363636
# 3861         603  2000   1.171774
# 4285           9  1965        NaN
# 4805           9  1980        NaN
# 4814          26  1977        NaN
# 4836          91  1957        NaN
# 4856          22  1982   2.333333
# 4939           4  2001        NaN
# 5692          38  1961        NaN
# 5961          15  1982        NaN
# 6758           9  1957        NaN
# 7208        3758  2004   3.612906
# 7250           8  1989        NaN
# 7460         196  2002        NaN
# 7631          28  1968   0.857543
# 8073         116  2003        NaN
# 8187         671  2004  60.680000
# 8212         194  2004        NaN
# 8295          29  1920        NaN
# 8687           5  1971        NaN
# 8865          18  1985        NaN
# 9409          16  2002        NaN
# 9421           2  2003        NaN
# 10531         25  1972        NaN
# 11324         15  1940        NaN
# 11584          0  1968        NaN
# 12297         24  1999        NaN
# 12364         85  2007   4.998100
# 13024          0  1998        NaN
# ...          ...   ...        ...         ...
# 36384         12  2004        NaN
# 36413          3  2008        NaN
# 37145          4  1981        NaN
# 39197         13  2015        NaN
# 39235          6  1958        NaN
# 39602          0  1979        NaN
# 41334         14  2016        NaN
# 42059         53  2016        NaN
# 42428          0  2016        NaN
# 42509          3  2016        NaN
# 42595         14  2017        NaN
# 42998         65  1993        NaN
# 43060         62  2017        NaN
# 43079          3  2017        NaN
# 43226          1  2016        NaN
# 43353         52  2017   1.285714
# 43439          1  2016        NaN
# 43480          2  1987        NaN
# 43665          2  2013        NaN
# 43904          1  2014        NaN
# 43963          0  1999        NaN
# 44094         38  2011        NaN
# 44103          7  2006   0.783946
# 44173         43  2012        NaN
# 44251          5  1976        NaN
# 44271        160  2017        NaN
# 44301         10  2017        NaN
# 44344         26  2017        NaN
# 44624        598  2017        NaN
# 44969         28  2017        NaN
#
# [114 rows x 24 columns]

# %%
df_movies_sff.to_csv('movies_metadata_scififantasy.csv',sep=',')
