# %%
import pandas as pd
import numpy as np

# %%
df_movies_metadata = pd.read_csv('movies_metadata.csv')

# %%
print(df_movies_metadata.columns)
# Out:
# Index([u'adult', u'belongs_to_collection', u'budget', u'genres', u'homepage',
#        u'id', u'imdb_id', u'original_language', u'original_title', u'overview',
#        u'popularity', u'poster_path', u'production_companies',
#        u'production_countries', u'release_date', u'revenue', u'runtime',
#        u'spoken_languages', u'status', u'tagline', u'title', u'video',
#        u'vote_average', u'vote_count'],
#       dtype='object')

# %%
df_movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview    ...     release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1  When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2  A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4  Just when George Banks has recovered from his ...    ...       1995-02-10
#
#      revenue runtime                                   spoken_languages  \
# 0  373554033      81           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249     104  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0     101           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156     127           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911     106           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7       5415
# 1                      Jumanji  False          6.9       2413
# 2             Grumpier Old Men  False          6.5         92
# 3            Waiting to Exhale  False          6.1         34
# 4  Father of the Bride Part II  False          5.7        173
#
# [5 rows x 24 columns]

# %%
df_movies_metadata.shape
# Out:
# (45466, 24)

# %%
df_movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.7+ MB

# %%
# Remove features that are not useful
df_movies_metadata = df_movies_metadata.drop(['imdb_id'], axis=1)

# %%
df_movies_metadata[df_movies_metadata['original_title'] != df_movies_metadata['title']][['title', 'original_title']].head()
# Out:
#                         title                    original_title
# 28  The City of Lost Children        La Cité des Enfants Perdus
# 29             Shanghai Triad                         摇啊摇，摇到外婆桥
# 32           Wings of Courage  Guillaumet, les ailes du courage
# 57                The Postman                        Il postino
# 58           The Confessional                  Le confessionnal

# %%
df_movies_metadata = df_movies_metadata.drop('original_title', axis=1)

# %%
df_movies_metadata['revenue'] = df_movies_metadata['revenue'].replace(0, np.nan)

# %%
df_movies_metadata['budget'] = pd.to_numeric(df_movies_metadata['budget'], errors='coerce')
df_movies_metadata['budget'] = df_movies_metadata['budget'].replace(0, np.nan)
df_movies_metadata[df_movies_metadata['budget'].isnull()].shape
# Out:
# (36576, 22)

# %%
# Drop Adult movies
df_movies_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  - Written by Ørnås                                                                                                                   1
# Name: adult, dtype: int64

# %%
df_movies_metadata = df_movies_metadata.drop('adult', axis=1)

# %%
base_poster_url = 'http://image.tmdb.org/t/p/w185/'
df_movies_metadata['poster_path'] = base_poster_url + df_movies_metadata['poster_path']

# %%
# create the year feature
df_movies_metadata['year'] = pd.to_datetime(df_movies_metadata['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
# create the return feature
df_movies_metadata['return'] = df_movies_metadata['revenue'] / df_movies_metadata['budget']
df_movies_metadata[df_movies_metadata['return'].isnull()].shape
# Let's explore our dataset again
df_movies_metadata.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...       NaN
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...       NaN
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id original_language  \
# 0  http://toystory.disney.com/toy-story    862                en
# 1                                   NaN   8844                en
# 2                                   NaN  15602                en
# 3                                   NaN  31357                en
# 4                                   NaN  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  Just when George Banks has recovered from his ...    8.38752
#
#                                          poster_path  \
# 0  http://image.tmdb.org/t/p/w185//rhIRbceoE9lR4v...
# 1  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 2  http://image.tmdb.org/t/p/w185//6ksm1sjKMFLbO7...
# 3  http://image.tmdb.org/t/p/w185//16XOMpEaLWkrcP...
# 4  http://image.tmdb.org/t/p/w185//e64sOI48hQXyru...
#
#                                 production_companies    ...     runtime  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]    ...          81
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...         104
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    ...         101
# 3  [{'name': 'Twentieth Century Fox Film Corporat...    ...         127
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...    ...         106
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year     return
# 0                    Toy Story  False          7.7       5415  1995  12.451801
# 1                      Jumanji  False          6.9       2413  1995   4.043035
# 2             Grumpier Old Men  False          6.5         92  1995        NaN
# 3            Waiting to Exhale  False          6.1         34  1995   5.090760
# 4  Father of the Bride Part II  False          5.7        173  1995        NaN
#
# [5 rows x 23 columns]

# %%
# Filter only on Science Fiction and Fantasy
df_movies_sff = df_movies_metadata[df_movies_metadata['genres'].str.contains("Science Fiction|Fantasy")]
df_movies_sff.shape
# Out:
# (4844, 23)

# %%
# Let's explore our dataset again
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN  65000000
# 23                                                NaN       NaN
# 28                                                NaN  18000000
# 31                                                NaN  29500000
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies    ...    runtime  \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...        104
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...    ...        111
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...    ...        108
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...        129
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...         89
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year    return
# 1                     Jumanji  False          6.9       2413  1995  4.043035
# 23                     Powder  False          6.3        143  1995       NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.096589
# 31             Twelve Monkeys  False          7.4       2470  1995  5.723390
# 33                       Babe  False          6.0        756  1995  8.471164
#
# [5 rows x 23 columns]

# %%
# Add sub-genres
# - alien
# - ai
# - time_travel
# - superhero
# - dystopian
# - space
# Approach: Create new column called sub_genres
# if overview column contains word, append that word + '/' to the cell in sub_genres

# Create new column called sub_genres
df_movies_sff.loc['sub_genres'] = ''
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN   6.5e+07
# 23                                                NaN       NaN
# 28                                                NaN   1.8e+07
# 31                                                NaN  2.95e+07
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...     3e+07
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies    ...      \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...    ...
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...    ...
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year     return  \
# 1                     Jumanji  False          6.9       2413  1995    4.04303
# 23                     Powder  False          6.3        143  1995        NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.0965895
# 31             Twelve Monkeys  False          7.4       2470  1995    5.72339
# 33                       Babe  False            6        756  1995    8.47116
#
#    sub_genres
# 1         NaN
# 23        NaN
# 28        NaN
# 31        NaN
# 33        NaN
#
# [5 rows x 24 columns]

# %%
df_movies_sff.loc[df_movies_sff['overview'].str.contains("alien", na=False),'sub_genres'] = 'alien,'
# Out:
# /usr/local/Cellar/python/2.7.12/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_movies_sff.loc[df_movies_sff['overview'].str.contains("space", na=False),'sub_genres'] = df_movies_sff['sub_genres'].astype(str) + 'space,'
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_movies_sff.loc[df_movies_sff['overview'].str.contains("space", na=False)]
# Out:
#                                    belongs_to_collection    budget  \
# 240                                                  NaN       NaN
# 760    {'id': 304378, 'name': 'Independence Day Colle...   7.5e+07
# 1171   {'id': 8091, 'name': 'Alien Collection', 'post...   1.1e+07
# 1255                                                 NaN   1.9e+06
# 1322   {'id': 151, 'name': 'Star Trek: The Original S...   3.5e+07
# 1432   {'id': 286162, 'name': 'Power Rangers Collecti...     1e+07
# 1568                                                 NaN   1.6e+07
# 1575                                                 NaN   3.6e+07
# 1684                                                 NaN   7.5e+07
# 1724                                                 NaN     8e+07
# 1808                                                 NaN   1.4e+08
# 1815                                                 NaN     60000
# 2198   {'id': 4438, 'name': 'The Space Odyssey Series...   2.8e+07
# 2264                                                 NaN   2.5e+07
# 2385                                                 NaN   6.5e+07
# 2420   {'id': 1709, 'name': 'Planet of the Apes Origi...   2.5e+06
# 2529   {'id': 8537, 'name': 'Superman Collection', 'p...   1.7e+07
# 2546                                                 NaN       NaN
# 2550                                                 NaN       NaN
# 2594   {'id': 256377, 'name': 'The Muppet Collection'...   2.4e+07
# 2916                                                 NaN  2.27e+07
# 3058                                                 NaN   4.5e+07
# 3344                                                 NaN   5.5e+07
# 3382                                                 NaN       NaN
# 3470                                                 NaN       NaN
# 3516   {'id': 645, 'name': 'James Bond Collection', '...   3.4e+07
# 3536   {'id': 123726, 'name': 'Quatermass (Hammer ser...       NaN
# 3658                                                 NaN       NaN
# 4458                                                 NaN     1e+07
# 4573                                                 NaN       NaN
# ...                                                  ...       ...
# 40782                                                NaN   1.3e+06
# 40990                                                NaN       NaN
# 41176                                                NaN       NaN
# 41536                                                NaN   1.1e+08
# 41918                                                NaN    250000
# 42167                                                NaN       NaN
# 42756                                                NaN       NaN
# 43044                                                NaN       NaN
# 43181                                                NaN       NaN
# 43263                                                NaN     1e+06
# 43279                                                NaN       NaN
# 43324                                                NaN       NaN
# 43450                                                NaN       NaN
# 43463                                                NaN       NaN
# 43702                                                NaN       NaN
# 43814                                                NaN       NaN
# 43851                                                NaN       NaN
# 43955                                                NaN       NaN
# 43970                                                NaN       NaN
# 44154                                                NaN       NaN
# 44212                                                NaN       NaN
# 44219                                                NaN       NaN
# 44220                                                NaN       NaN
# 44223                                                NaN       NaN
# 44229                                                NaN       NaN
# 44446                                                NaN       NaN
# 44485                                                NaN       NaN
# 44726                                                NaN       NaN
# 45367                                                NaN       NaN
# 45425                                                NaN       NaN
#
#                                                   genres  \
# 240    [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...
# 760    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1171   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 1255   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1322   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1432   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1568   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1575   [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 1684            [{'id': 878, 'name': 'Science Fiction'}]
# 1724   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 1808   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 1815   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2198   [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 2264   [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
# 2385   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2420   [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2529   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2546   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2550   [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2594   [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 2916   [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 3058   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3344   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 3382   [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 3470   [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 3516   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3536   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 3658            [{'id': 878, 'name': 'Science Fiction'}]
# 4458   [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...
# 4573   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# ...                                                  ...
# 40782  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 40990  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 41176  [{'id': 53, 'name': 'Thriller'}, {'id': 12, 'n...
# 41536  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 41918  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 42167  [{'id': 53, 'name': 'Thriller'}, {'id': 12, 'n...
# 42756  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 43044  [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# 43181  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 43263           [{'id': 878, 'name': 'Science Fiction'}]
# 43279  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 43324  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 43450  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 43463  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 43702  [{'id': 10770, 'name': 'TV Movie'}, {'id': 18,...
# 43814  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 43851  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 43955           [{'id': 878, 'name': 'Science Fiction'}]
# 43970           [{'id': 878, 'name': 'Science Fiction'}]
# 44154  [{'id': 10770, 'name': 'TV Movie'}, {'id': 27,...
# 44212  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 44219  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 44220  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 44223           [{'id': 878, 'name': 'Science Fiction'}]
# 44229           [{'id': 878, 'name': 'Science Fiction'}]
# 44446  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 44485  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 44726  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 45367           [{'id': 878, 'name': 'Science Fiction'}]
# 45425  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
#
#                                                 homepage      id  \
# 240                                                  NaN   43475
# 760                                                  NaN     602
# 1171            https://www.facebook.com/alienanthology/     348
# 1255                                                 NaN     830
# 1322                                                 NaN     152
# 1432                                                 NaN    6499
# 1568                                                 NaN   36797
# 1575                                                 NaN     782
# 1684   http://www.warnerbros.com/movies/home-entertai...   10153
# 1724                                                 NaN    2157
# 1808                                                 NaN      95
# 1815                                                 NaN   10513
# 2198                                                 NaN    4437
# 2264                                                 NaN   11954
# 2385                                                 NaN    9849
# 2420                                                 NaN    1687
# 2529                                                 NaN   11411
# 2546                                                 NaN   19483
# 2550                                                 NaN   18158
# 2594                                                 NaN   10208
# 2916      http://www.mgm.com/view/movie/1873/Spaceballs/     957
# 3058                                                 NaN     926
# 3344                                                 NaN    2102
# 3382                                                 NaN     593
# 3470                                                 NaN   22501
# 3516       http://www.mgm.com/view/movie/1292/Moonraker/     698
# 3536                                                 NaN   26912
# 3658                                                 NaN   37744
# 4458                                                 NaN    2210
# 4573                                                 NaN   21596
# 44726   0.398256  http://image.tmdb.org/t/p/w185//vaKwT78qQ7Llw7...
# 45367    3.5e-05  http://image.tmdb.org/t/p/w185//aWnsJwOZB1ARha...
# 45425   0.630944  http://image.tmdb.org/t/p/w185//sQWV6lKyOGHt8L...
#
#                                     production_companies       ...         \
# 240                                                   []       ...
# 760    [{'name': 'Twentieth Century Fox Film Corporat...       ...
# 1171   [{'name': 'Twentieth Century Fox Film Corporat...       ...
# 1255   [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8...       ...
# 1322           [{'name': 'Paramount Pictures', 'id': 4}]       ...
# 1432   [{'name': 'Twentieth Century Fox Film Corporat...       ...
# 1568   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...       ...
# 1575   [{'name': 'Columbia Pictures', 'id': 5}, {'nam...       ...
# 1684   [{'name': 'Punch Productions', 'id': 2154}, {'...       ...
# 1724   [{'name': 'New Line Cinema', 'id': 12}, {'name...       ...
# 1808   [{'name': 'Jerry Bruckheimer Films', 'id': 130...       ...
# 1815        [{'name': 'Reynolds Pictures', 'id': 74116}]       ...
# 2198   [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8...       ...
# 2264   [{'name': 'TriStar Pictures', 'id': 559}, {'na...       ...
# 2385         [{'name': 'Walt Disney Pictures', 'id': 2}]       ...
# 2420   [{'name': 'Twentieth Century Fox Film Corporat...       ...
# 2529   [{'name': 'Cannon Films', 'id': 4110}, {'name'...       ...
# 2546   [{'name': 'Universal International Pictures (U...       ...
# 2550   [{'name': 'Columbia Pictures Corporation', 'id...       ...
# 2594   [{'name': 'Columbia Pictures', 'id': 5}, {'nam...       ...
# 2916   [{'name': 'Brooksfilms Ltd.', 'id': 617}, {'na...       ...
# 3058   [{'name': 'DreamWorks SKG', 'id': 27}, {'name'...       ...
# 3344   [{'name': 'Japan America Picture Company', 'id...       ...
# 3382   [{'name': 'Mosfilm', 'id': 5120}, {'name': 'Cr...       ...
# 3470   [{'name': 'British Broadcasting Corporation (B...       ...
# 3516   [{'name': 'United Artists', 'id': 60}, {'name'...       ...
# 3536   [{'name': 'Hammer Film Productions', 'id': 1314}]       ...
# 3658          [{'name': 'Lippert Pictures', 'id': 4946}]       ...
# 4458   [{'name': 'De Laurentiis Entertainment Group (...       ...
# 4573       [{'name': 'Entre Chien et Loup', 'id': 3984}]       ...
# ...                                                  ...       ...
# 40782  [{'name': 'Ecaveo Capital Partners', 'id': 770...       ...
# 40990  [{'name': 'Titan Productions', 'id': 1582}, {'...       ...
# 41176      [{'name': 'Epic Pictures Group', 'id': 7662}]       ...
# 41536  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...       ...
# 41918  [{'name': 'Nautilus Film Company, The', 'id': ...       ...
# 42167  [{'name': 'Eenie Ienie Over Productions', 'id'...       ...
# 42756      [{'name': 'California Pictures', 'id': 8189}]       ...
# 43044      [{'name': 'A.I.P. Productions', 'id': 18008}]       ...
# 43181       [{'name': 'Longview Pictures', 'id': 87214}]       ...
# 43263     [{'name': 'Thousand Mile Media', 'id': 51117}]       ...
# 43279  [{'name': 'Media Plus', 'id': 6108}, {'name': ...       ...
# 43324            [{'name': 'Idea Factory', 'id': 59266}]       ...
# 43450         [{'name': 'MT2 Productions', 'id': 86979}]       ...
# 43463  [{'name': 'Favorit Film', 'id': 19601}, {'name...       ...
# 43702  [{'name': 'Left Bank Pictures', 'id': 5340}, {...       ...
# 43814  [{'name': 'B.I. & L. Releasing Corp.', 'id': 1...       ...
# 43851                                                 []       ...
# 43955                                                 []       ...
# 43970        [{'name': 'Gorky Film Studio', 'id': 3681}]       ...
# 44154  [{'name': 'NBC Universal Television', 'id': 19...       ...
# 44212                                                 []       ...
# 44219  [{'name': 'Official Films', 'id': 19742}, {'na...       ...
# 44220  [{'name': 'Official Films', 'id': 19742}, {'na...       ...
# 44223  [{'name': 'Woolner Brothers Pictures Inc.', 'i...       ...
# 44229  [{'name': 'Columbia Pictures Corporation', 'id...       ...
# 44446                                                 []       ...
# 44485       [{'name': 'Wildstreet Pictures', 'id': 993}]       ...
# 44726          [{'name': 'Robert W. Paul', 'id': 44944}]       ...
# 45367         [{'name': 'BBV Productions', 'id': 88355}]       ...
# 45425                  [{'name': 'Mosfilm', 'id': 5120}]       ...
#
#                                         spoken_languages    status  \
# 240             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 760             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1171   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1255            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1322            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1432            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1568            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1575   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1684            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1724            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1808   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1815            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2198   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2264   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2385   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2420            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2529   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2546            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2550            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2594            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2916            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3058            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3344            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3382            [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 3470           [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 3516   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 3536            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3658            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4458            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4573           [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# ...                                                  ...       ...
# 40782           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40990           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 41176           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 41536           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 41918           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 42167           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 42756           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43044           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43181           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43263           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43279  [{'iso_639_1': 'sr', 'name': 'Srpski'}, {'iso_...  Released
# 43324               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 43450           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43702           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43814           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43851           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43955           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 43970           [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 44154           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44212  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 44219           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44220           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44223           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44229           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44446           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44485           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44726       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 45367           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45425           [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
#
#                                                  tagline  \
# 240                             The original green hero!
# 760      Earth. Take a good look. It might be your last.
# 1171                In space no one can hear you scream.
# 1255   Earthmen on a fabulous, peril-journey into out...
# 1322              The human adventure is just beginning.
# 1432                                  The Power Is Back!
# 1568                          He's just taking up space!
# 1575              There is no gene for the human spirit.
# 1684   A thousand feet beneath the sea, the blackest ...
# 1724                              Danger, Will Robinson!
# 1808   The Earth's Darkest Day Will Be Man's Finest Hour
# 1815   Unspeakable Horrors From Outer Space Paralyze ...
# 2198            "Something wonderful is going to happen"
# 2264          In the blink of an eye, the terror begins.
# 2385   The martian has landed. There goes the neighbo...
# 2420        Meet baby Milo who has Washington terrified.
# 2529   Nuclear Power. In the best hands, it is danger...
# 2546                   Fantastic sights leap out at you!
# 2550          The terrifying truth about flying saucers!
# 2594               Space. It's not as deep as you think.
# 2916                        May the schwartz be with you
# 3058                   A comedy of Galactic Proportions.
# 3344   In the year 2050, the battle to save the earth...
# 3382                                                 NaN
# 3470                                                 NaN
# 3516                     Outer space now belongs to 007.
# 3536                   World in panic! Cities in flames!
# 3658   The screen's first story of man's conquest of ...
# 4458   Valerie's about to discover how far a girl has...
# 4573                                                 NaN
# ...                                                  ...
# 40782                   One Man, One Mission, One Choice
# 40990              Big Movie. Big Production. Big Girls.
# 41176                                                NaN
# 41536                    There is a reason they woke up.
# 41918                    What comes after World War III?
# 42167  Their mission was to reach the edge of the uni...
# 42756                                  Survive the void.
# 43044    There Is Nowhere To Hide From The Enemy Within.
# 43181                         He is mankind's only hope.
# 43263        In a Perfect World...There is a Fatal Flaw.
# 43279                                      Death is dead
# 43324                                                NaN
# 43450                                                NaN
# 43463                                                NaN
# 43702                                                NaN
# 43814               A way-out tale of a far-out monster!
# 43851                                                NaN
# 43955                                                NaN
# 43970                                                NaN
# 44154                                                NaN
# 44212            The Fate of the Earth is in Their Hands
# 44219                                                NaN
# 44220                                                NaN
# 44223                   Made to Kill or Love on Command!
# 44229  Ride the Excitement Orbit to the Moon with the...
# 44446                                                NaN
# 44485  Beyond Rescue ... Beyond Reason ... Beyond Sal...
# 44726                                                NaN
# 45367                                                NaN
# 45425                                                NaN
#
#                                                    title  video vote_average  \
# 240                                     Gumby: The Movie  False            5
# 760                                     Independence Day  False          6.7
# 1171                                               Alien  False          7.9
# 1255                                    Forbidden Planet  False          7.2
# 1322                       Star Trek: The Motion Picture  False          6.2
# 1432                        Turbo: A Power Rangers Movie  False          4.6
# 1568                                           RocketMan  False          5.4
# 1575                                             Gattaca  False          7.5
# 1684                                              Sphere  False          5.8
# 1724                                       Lost in Space  False            5
# 1808                                          Armageddon  False          6.5
# 1815                             Plan 9 from Outer Space  False          4.4
# 2198                                                2010  False          6.6
# 2264                                           Lifeforce  False          6.2
# 2385                                 My Favorite Martian  False          5.1
# 2420                  Escape from the Planet of the Apes  False          6.3
# 2529                    Superman IV: The Quest for Peace  False          4.1
# 2546                            It Came from Outer Space  False          6.2
# 2550                        Earth vs. the Flying Saucers  False            6
# 2594                                  Muppets from Space  False          5.8
# 2916                                          Spaceballs  False          6.7
# 3058                                        Galaxy Quest  False          6.9
# 3344                                        Solar Crisis  False          4.4
# 3382                                             Solaris  False          7.7
# 3470                                        Time Masters  False          7.4
# 3516                                           Moonraker  False          5.9
# 3536                              Quatermass and the Pit  False          6.2
# 3658                                      Rocketship X-M  False          5.1
# 4458                                Earth Girls Are Easy  False          5.5
# 4573                                      Thomas in Love  False            6
# ...                                                  ...    ...          ...
# 40782                                            Capsule  False          5.2
# 40990                   Slave Girls from Beyond Infinity  False          5.8
# 41176                                             Somnus  False          4.9
# 41536                                         Passengers  False          6.7
# 41918                                      The Aftermath  False          4.7
# 42167                                            ISRA 88  False            5
# 42756                                         Scavengers  False          2.7
# 43044                                       Space Mutiny  False          2.3
# 43181                                        Lone Wolves  False            3
# 43263                                            Teleios  False          5.2
# 43279                                           The Rift  False          4.3
# 43324                                Mars of Destruction  False            2
# 43450                             Moontrap: Target Earth  False            4
# 43463                                 Shockwave Darkside  False          1.5
# 43702                                              Oasis   True            7
# 43814                                    Monster a-Go Go  False          2.3
# 43851                                       Project: ALF  False          5.1
# 43955                                    Alive in Joburg  False            7
# 43970                          To The Stars By Hard Ways  False            5
# 44154                                       Star Runners  False          5.2
# 44212                          Extraterrestrial Visitors  False          2.2
# 44219                                   Manhunt in Space  False            1
# 44220                                     Crash of Moons  False            3
# 44223                              The Human Duplicators  False            2
# 44229                                     12 to the Moon  False          2.6
# 44446                                       Star Command  False          4.3
# 44485                          The Dark Side of The Moon  False          4.7
# 44726                                   The '?' Motorist  False          6.8
# 45367                  The Stranger: Summoned by Shadows  False            0
# 45425  A Black Rose Is an Emblem of Sorrow, a Red Ros...  False          6.5
#
#       vote_count  year    return       sub_genres
# 240            2  1995       NaN  nanspace,space,
# 760         3334  1996   10.8929     alien,space,
# 1171        4564  1979   9.53925     alien,space,
# 1255         238  1956   1.71053  nanspace,space,
# 1322         541  1979   3.97143  nanspace,space,
# 1432          60  1997   1.79797  nanspace,space,
# 1568          36  1997       NaN  nanspace,space,
# 1575        1846  1997  0.348133  nanspace,space,
# 1684         483  1998  0.174667  nanspace,space,
# 1724         395  1998   1.70199  nanspace,space,
# 1808        2540  1998   3.95571  nanspace,space,
# 1815         137  1959       NaN     alien,space,
# 2198         290  1984   1.44288  nanspace,space,
# 2264         136  1985       NaN     alien,space,
# 2385          81  1999  0.566925  nanspace,space,
# 2420         270  1971   4.93956  nanspace,space,
# 2529         327  1987   1.13529  nanspace,space,
# 2546          52  1953       NaN  nanspace,space,
# 2550          41  1956       NaN     alien,space,
# 2594          94  1999  0.678791     alien,space,
# 2916         924  1987   1.67927  nanspace,space,
# 3058         722  1999    2.0152     alien,space,
# 3344           7  1990       NaN  nanspace,space,
# 3382         364  1972       NaN  nanspace,space,
# 3470          38  1982       NaN  nanspace,space,
# 3516         551  1979   6.18553  nanspace,space,
# 3536          57  1967       NaN  nanspace,space,
# 3658          15  1950       NaN  nanspace,space,
# 4458         110  1988   0.39163     alien,space,
# 4573           2  2000       NaN  nanspace,space,
# ...          ...   ...       ...              ...
# 40782         26  2015       NaN  nanspace,space,
# 40990          8  1987       NaN  nanspace,space,
# 41176          8  2016       NaN  nanspace,space,
# 41536       4134  2016   2.75586  nanspace,space,
# 41918          8  1982       NaN  nanspace,space,
# 42167         13  2016       NaN  nanspace,space,
# 42756          9  2013       NaN     alien,space,
# 43044         18  1988       NaN  nanspace,space,
# 43181          5  2016       NaN  nanspace,space,
# 43263         20  2017       NaN  nanspace,space,
# 43279         12  2016       NaN  nanspace,space,
# 43324          1  2005       NaN  nanspace,space,
# 43450          8  2017       NaN  nanspace,space,
# 43463          2  2014       NaN  nanspace,space,
# 43702          2  2017       NaN  nanspace,space,
# 43814         14  1965       NaN  nanspace,space,
# 43851         10  1996       NaN     alien,space,
# 43955         28  2005       NaN     alien,space,
# 43970         10  1980       NaN     alien,space,
# 44154          9  2009       NaN  nanspace,space,
# 44212         14  1983       NaN     alien,space,
# 44219          1  1956       NaN  nanspace,space,
# 44220          3  1954       NaN  nanspace,space,
# 44223          3  1965       NaN     alien,space,
# 44229          4  1960       NaN     alien,space,
# 44446          4  1996       NaN  nanspace,space,
# 44485         11  1990       NaN  nanspace,space,
# 44726         10  1906       NaN  nanspace,space,
# 45367          0  1991       NaN  nanspace,space,
# 45425          4  1989       NaN  nanspace,space,
#
# [281 rows x 24 columns]
