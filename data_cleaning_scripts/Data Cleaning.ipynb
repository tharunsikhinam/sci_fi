# %%
import pandas as pd
import numpy as np

# %%
df_movies_metadata = pd.read_csv('movies_metadata.csv')

# %%
print(df_movies_metadata.columns)
# Out:
# Index([u'adult', u'belongs_to_collection', u'budget', u'genres', u'homepage',
#        u'id', u'imdb_id', u'original_language', u'original_title', u'overview',
#        u'popularity', u'poster_path', u'production_companies',
#        u'production_countries', u'release_date', u'revenue', u'runtime',
#        u'spoken_languages', u'status', u'tagline', u'title', u'video',
#        u'vote_average', u'vote_count'],
#       dtype='object')

# %%
df_movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview    ...     release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1  When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2  A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4  Just when George Banks has recovered from his ...    ...       1995-02-10
#
#      revenue runtime                                   spoken_languages  \
# 0  373554033      81           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249     104  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0     101           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156     127           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911     106           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7       5415
# 1                      Jumanji  False          6.9       2413
# 2             Grumpier Old Men  False          6.5         92
# 3            Waiting to Exhale  False          6.1         34
# 4  Father of the Bride Part II  False          5.7        173
#
# [5 rows x 24 columns]

# %%
df_movies_metadata.shape
# Out:
# (45466, 24)

# %%
df_movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.7+ MB

# %%
# Remove features that are not useful
df_movies_metadata = df_movies_metadata.drop(['imdb_id'], axis=1)

# %%
df_movies_metadata[df_movies_metadata['original_title'] != df_movies_metadata['title']][['title', 'original_title']].head()
# Out:
#                         title                    original_title
# 28  The City of Lost Children        La Cité des Enfants Perdus
# 29             Shanghai Triad                         摇啊摇，摇到外婆桥
# 32           Wings of Courage  Guillaumet, les ailes du courage
# 57                The Postman                        Il postino
# 58           The Confessional                  Le confessionnal

# %%
df_movies_metadata = df_movies_metadata.drop('original_title', axis=1)

# %%
df_movies_metadata['revenue'] = df_movies_metadata['revenue'].replace(0, np.nan)

# %%
df_movies_metadata['budget'] = pd.to_numeric(df_movies_metadata['budget'], errors='coerce')
df_movies_metadata['budget'] = df_movies_metadata['budget'].replace(0, np.nan)
df_movies_metadata[df_movies_metadata['budget'].isnull()].shape
# Out:
# (36576, 22)

# %%
# Drop Adult movies
df_movies_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  - Written by Ørnås                                                                                                                   1
# Name: adult, dtype: int64

# %%
df_movies_metadata = df_movies_metadata.drop('adult', axis=1)

# %%
base_poster_url = 'http://image.tmdb.org/t/p/w185/'
df_movies_metadata['poster_path'] = base_poster_url + df_movies_metadata['poster_path']

# %%
# create the year feature
df_movies_metadata['year'] = pd.to_datetime(df_movies_metadata['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
# create the return feature
df_movies_metadata['return'] = df_movies_metadata['revenue'] / df_movies_metadata['budget']
df_movies_metadata[df_movies_metadata['return'].isnull()].shape
# Let's explore our dataset again
df_movies_metadata.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...       NaN
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...       NaN
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id original_language  \
# 0  http://toystory.disney.com/toy-story    862                en
# 1                                   NaN   8844                en
# 2                                   NaN  15602                en
# 3                                   NaN  31357                en
# 4                                   NaN  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...    3.85949
# 4  Just when George Banks has recovered from his ...    8.38752
#
#                                          poster_path  \
# 0  http://image.tmdb.org/t/p/w185//rhIRbceoE9lR4v...
# 1  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 2  http://image.tmdb.org/t/p/w185//6ksm1sjKMFLbO7...
# 3  http://image.tmdb.org/t/p/w185//16XOMpEaLWkrcP...
# 4  http://image.tmdb.org/t/p/w185//e64sOI48hQXyru...
#
#                                 production_companies    ...     runtime  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]    ...          81
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...         104
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    ...         101
# 3  [{'name': 'Twentieth Century Fox Film Corporat...    ...         127
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...    ...         106
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year     return
# 0                    Toy Story  False          7.7       5415  1995  12.451801
# 1                      Jumanji  False          6.9       2413  1995   4.043035
# 2             Grumpier Old Men  False          6.5         92  1995        NaN
# 3            Waiting to Exhale  False          6.1         34  1995   5.090760
# 4  Father of the Bride Part II  False          5.7        173  1995        NaN
#
# [5 rows x 23 columns]

# %%
# Filter only on Science Fiction and Fantasy
df_movies_sff = df_movies_metadata[df_movies_metadata['genres'].str.contains("Science Fiction|Fantasy")]
df_movies_sff.shape
# Out:
# (4844, 23)

# %%
# Let's explore our dataset again
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN  65000000
# 23                                                NaN       NaN
# 28                                                NaN  18000000
# 31                                                NaN  29500000
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies    ...    runtime  \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...    ...        104
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...    ...        111
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...    ...        108
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...        129
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...    ...         89
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year    return
# 1                     Jumanji  False          6.9       2413  1995  4.043035
# 23                     Powder  False          6.3        143  1995       NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.096589
# 31             Twelve Monkeys  False          7.4       2470  1995  5.723390
# 33                       Babe  False          6.0        756  1995  8.471164
#
# [5 rows x 23 columns]

# %%
# Sub-genre List
# - alien (Alien)
# - monster (Monster)
# - space (Space Opera)
# - robot (AI/Robot)
# - time_travel (Time Travel)
# - super (Superheroes)
# - dystopian (Dystopian)
# - fantasy (Fantasy)
# - techno (Technology Thriller)
# Approach: Create new column called sub_genres
# if overview column contains word, append that word + '/' to the cell in sub_genres

# Create new column called sub_genres
df_movies_sff['sub_genres'] = ''
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def search(df, words):  #1
    """
    Return a sub-DataFrame of those rows whose column match any of the words.
    """
    return df[np.logical_or.reduce([df.select_dtypes(include=[object]).stack().\
                                    str.contains(word, case=False, na=False).unstack().any(1) for word in words])]   # 2

# %%
alien_keywords = [
  'saucer',
  'alien',
  'life',
  'human',
  'extraterrestrial',
  'ufo',
  'parasite',
  'meteorite',
  'meteor',
  'ET',
  'saucers',
  'aliens',
  'extraterrestrials',
  'ufos',
  'parasites',
  'meteorites',
  'meteors',
  'supernatural',
  'xenomorph',
  'area 51',
  'xenomorphs',
]

space_keywords = [
  'luke',
  'star',
  'spaceship',
  'battle',
  'interstellar',
  'planet',
  'enterprise',
  'skywalker',
  'darth',
  'droid'
  'earth',
  'spock',
  'kirk',
  'space',
  'capt',
  'moon',
  'spacecraft',
  'crew',
  'comet',
  'mars',
  'galaxy', 'nebula', 'astronaut', 'galaxies', 'nebulas', 'astronauts', 'stars', 'spaceships', 'battles', 'planets', 'droids', 'moons', 'spacecrafts', 'comets', 'jupiter', 'pluto', 'venus', 'sun', 'suns', 'neptune', 'asteroid', 'asteroids', 'meteor', 'meteors', 'meteorites', 'meteorite', 'mercury', 'antimatter', 'black hole', 'celestial', 'comet', 'comets', 'cosmic', 'constellation', 'exoplanet', 'lodestar', 'milky way', 'nova', 'supernova', 'pulsar', 'quasar', 'satellite', 'satellites', 'solar', 'world', 'eclipse', 'universe', 'interplanetary',
]

robot_keywords = [
  'cop',
  'ai',
  'cyborg',
  'terminator',
  'army',
  'android',
  'weapon',
  'robot',
  'intelligence',
  'machine',
  'artificial', 'mech', 'machina', 'mecha', 'cyborgs', 'terminators', 'armies', 'androids', 'droid', 'droids', 'weapons', 'robots', 'machines', 'robotic', 'robotics', 'automaton', 'automatons', 'bot', 'bots', 'bionic', 'bionics', 'mechanism', 'mechanisms',

]

time_travel_keywords = [
  'travel',
  'time',
  'back',
  'frozen',
  'spacetime', 'eternalism', 'futurity', 'future', 'past',

]

super_keywords = [
  'marvel',
  'superman',
  'superpower',
  'super',
  'powers', 'ability', 'abilities', 'dc', 'gifted', 'x-men', 'hero', 'heroes',
]

dystopian_keywords = ['virus', 'future', 'nuclear', 'city', 'epidemic', 'prison', 'dark', 'murder', 'evil', 'violence', 'experiment'\
                      'totalitarian', 'society', 'post-apocalyptic', 'dystopian', 'experiments', 'sinister', 'futuristic', \
                      'radiation', 'biblical', 'mysterious', 'military', 'spy', 'heavenly', 'cloning', 'nazi', 'reich',\
                      'death', 'war', 'drug', 'wasteland',
                      'mutant', 'mutants', 'mutation', 'mutations', 'viruses', 'epidemics', 'clone', 'communism', 'communist', 'communists', 'dystopia', 'clones', 'wastelands', 'apocalypse', 'alternate', 'reality', 'bleak', 'dead', 'zombie', 'zombies', 'apes', 'drought', 'lack', 'dwindling', 'atmosphere', 'cyberpunk', 'political', 'unethical', 'raiders', 'raider',

]

monster_keywords = ['frankenstein', 'vampire', 'werewolf', 'shark', 'spider', 'zombie', 'blob', 'creature', 'troll', 'gypsy', 'ape'\
                      'dinosaur', 'jurassic', 'scientist', 'swamp', 'dinosaurs', 'monster', 'octopus', 'godzilla', 'scorpion',\
                      'ants', 'golem', 'giants', 'serpent', 'crocodile', 'bermuda', 'mutant', 'mutants', 'mutation', 'mutations', 'vampires', 'werewolves', 'sharks', 'spiders', 'zombies', 'dead', 'creatures', 'apes', 'scientists', 'evil', 'swamps', 'monsters', 'octopi', 'scorpions', 'reptile', 'reptilian', 'golems', 'giant', 'hulking', 'serpentine', 'crocodiles', 'genetic', 'engineered', 'aberration', 'beast', 'beasts', 'humanoid', 'humanoids', 'folklore', 'spirit', 'spirits', 'freak', 'demon', 'freaks', 'demons', 'ogre', 'ogres', 'orc', 'orcs', 'elf', 'elves', 'bogeyman', 'behemoth', 'behemoths', 'monstrosity', 'monstrosities', 'colossal', 'colossus', 'leviathan', 'leviathans', 'dracula', 'monstrous', 'ghost', 'ghosts', 'specter', 'specters', 'phantom', 'phantoms', 'apparition', 'apparitions', 'wraith', 'wraiths', 'chimera', 'chimeras',

]

techno_keywords = ['computer', 'cyber', 'matrix', 'chip', 'network', 'serum', 'data', 'virtual', 'reality', 'laser', 'video', 'game'\
                      'player', 'tech', 'memory', 'database', 'computers', 'program', 'matrices', 'databases', 'serums', 'technology', 'technologies', 'code', 'coded', 'codes', 'coding', 'coder', 'coders', 'simulator', 'simulation', 'simulators', 'simulations', 'programs', 'gadget', 'gadgets', 'electronic', 'electronics', 'cyberpunk', 'cyber', 'cybers', 'nano', 'nanotechnology', 'nanotechnologies', 'biotech', 'biotechnology', 'biotechnologies', 'software', 'softwares', 'digital',

]

fantasy_keywords = ['magic', 'magical', 'wizard', 'wizards', 'witch', 'witches', 'wizardry', 'spells', 'spell casting', 'spell caster', 'wand', 'wands', 'hobbit', 'elf', 'elves', 'orc', 'orcs', 'dragon', 'dragons', 'quest', 'quests', 'dwarves', 'dwarven', 'dwarf', 'hobbits', 'elven', 'cursed', 'curse', 'curses', 'goblin', 'goblins', 'spirit', 'spirits', 'wizarding', 'enchant', 'enchantment', 'enchantments', 'enchanted', 'enchanting', 'potion', 'potions', 'alchemy', 'alchemist', 'chemist', 'apothecary', 'elder', 'elders', 'summoner']

# %%
df_movies_sff.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1                                                 NaN  65000000
# 23                                                NaN       NaN
# 28                                                NaN  18000000
# 31                                                NaN  29500000
# 33  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
#
#                                                genres homepage     id  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   8844
# 23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN  12665
# 28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN    902
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN     63
# 33  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...      NaN   9598
#
#    original_language                                           overview  \
# 1                 en  When siblings Judy and Peter discover an encha...
# 23                en  Harassed by classmates who won't accept his sh...
# 28                fr  A scientist in a surrealist society kidnaps ch...
# 31                en  In the year 2035, convict James Cole reluctant...
# 33                en  Babe is a little pig who doesn't quite know hi...
#
#    popularity                                        poster_path  \
# 1     17.0155  http://image.tmdb.org/t/p/w185//vzmL6fP7aPKNKP...
# 23    12.1331  http://image.tmdb.org/t/p/w185//1uRKsxOCtgz0xV...
# 28    9.82242  http://image.tmdb.org/t/p/w185//eVo6ewq4akfyJY...
# 31    12.2973  http://image.tmdb.org/t/p/w185//6Sj9wDu3YugthX...
# 33    14.4048  http://image.tmdb.org/t/p/w185//gN6X3fwPya8pLf...
#
#                                  production_companies     ...      \
# 1   [{'name': 'TriStar Pictures', 'id': 559}, {'na...     ...
# 23  [{'name': 'Caravan Pictures', 'id': 175}, {'na...     ...
# 28  [{'name': 'Procirep', 'id': 311}, {'name': 'Co...     ...
# 31  [{'name': 'Universal Pictures', 'id': 33}, {'n...     ...
# 33  [{'name': 'Universal Pictures', 'id': 33}, {'n...     ...
#
#                                      spoken_languages    status  \
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 23           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 31  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 33           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 1           Roll the dice and unleash the excitement!
# 23  An extraordinary encounter with another human ...
# 28          Where happily ever after is just a dream.
# 31                             The future is history.
# 33                      A little pig goes a long way.
#
#                         title  video vote_average vote_count  year    return  \
# 1                     Jumanji  False          6.9       2413  1995  4.043035
# 23                     Powder  False          6.3        143  1995       NaN
# 28  The City of Lost Children  False          7.6        308  1995  0.096589
# 31             Twelve Monkeys  False          7.4       2470  1995  5.723390
# 33                       Babe  False          6.0        756  1995  8.471164
#
#     sub_genres
# 1
# 23
# 28
# 31
# 33
#
# [5 rows x 24 columns]

# %%
# search(df_movies_sff, 'saucer', 'alien', 'life', 'human', 'extraterrestrial', 'ufo', 'parasite'\
                        #'meteorite', 'meteor').index
search(df_movies_sff, ['saucer', 'alien', 'life', 'human', 'extraterrestrial', 'ufo', 'parasite'\
                        'meteorite', 'meteor']).index
# Out:
# Int64Index([   23,    43,    59,    75,   155,   157,   169,   193,   198,
#               224,
#             ...
#             45191, 45203, 45337, 45346, 45353, 45356, 45375, 45429, 45444,
#             45445],
#            dtype='int64', length=1505)

# %%
df_movies_sff.loc[search(df_movies_sff, alien_keywords).index, 'sub_genres'] = 'alien/'

# %%
df_movies_sff.loc[search(df_movies_sff, space_keywords).index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'space/'

# %%
df_movies_sff.loc[search(df_movies_sff, robot_keywords).index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'robot/'

# %%
df_movies_sff.loc[search(df_movies_sff, time_travel_keywords).index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'time_travel/'

# %%
df_movies_sff.loc[search(df_movies_sff, super_keywords).index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'super/'

# %%
df_movies_sff.loc[search(df_movies_sff, dystopian_keywords).index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'dystopian/'

# %%
df_movies_sff.loc[df_movies_sff['genres'].str.contains("Fantasy", case='False', na=False), 'sub_genres'] = df_movies_sff['sub_genres'].astype(str) + 'fantasy/'

# %%
df_movies_sff.loc[search(df_movies_sff, monster_keywords).index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'monster/'

# %%
df_movies_sff.loc[search(df_movies_sff, techno_keywords).index, 'sub_genres'] \
= df_movies_sff['sub_genres'].astype(str) + 'techno/'

# %%
df_movies_sff['sub_genres'].value_counts()
# Out:
# alien/space/robot/dystopian/monster/                              126
# alien/space/robot/time_travel/dystopian/monster/                  125
# alien/space/robot/time_travel/dystopian/fantasy/monster/           98
# alien/robot/time_travel/dystopian/monster/                         77
# alien/robot/fantasy/                                               76
# alien/robot/time_travel/dystopian/fantasy/monster/                 75
# alien/space/robot/dystopian/fantasy/monster/                       75
# alien/space/dystopian/monster/                                     67
# alien/robot/dystopian/fantasy/monster/                             63
# alien/space/robot/dystopian/                                       62
# alien/robot/dystopian/monster/                                     60
# alien/fantasy/                                                     60
# alien/space/robot/time_travel/dystopian/                           58
# alien/space/robot/                                                 57
# fantasy/                                                           52
# alien/space/robot/time_travel/dystopian/monster/techno/            52
# alien/space/robot/time_travel/super/dystopian/fantasy/monster/     52
# alien/space/robot/monster/                                         49
# alien/robot/dystopian/fantasy/                                     49
# alien/robot/time_travel/dystopian/                                 49
# alien/space/time_travel/dystopian/monster/                         48
# alien/space/robot/fantasy/                                         45
# alien/robot/time_travel/fantasy/monster/                           44
# alien/dystopian/monster/                                           44
# alien/time_travel/dystopian/fantasy/monster/                       43
# alien/dystopian/fantasy/monster/                                   43
# alien/robot/fantasy/monster/                                       40
# alien/space/robot/time_travel/super/dystopian/monster/             39
# alien/robot/                                                       39
# alien/space/dystopian/fantasy/monster/                             39
#                                                                  ...
# time_travel/super/dystopian/fantasy/monster/                        1
# alien/space/time_travel/super/fantasy/monster/techno/               1
# robot/super/dystopian/fantasy/                                      1
# space/dystopian/fantasy/techno/                                     1
# alien/space/robot/time_travel/super/fantasy/techno/                 1
# alien/time_travel/dystopian/fantasy/techno/                         1
# space/robot/monster/techno/                                         1
# robot/dystopian/techno/                                             1
# space/robot/time_travel/super/dystopian/monster/techno/             1
# alien/time_travel/super/monster/                                    1
# alien/time_travel/dystopian/fantasy/monster/techno/                 1
# space/time_travel/super/dystopian/fantasy/                          1
# space/time_travel/monster/techno/                                   1
# alien/space/super/monster/techno/                                   1
# time_travel/super/dystopian/fantasy/                                1
# robot/time_travel/fantasy/techno/                                   1
# space/robot/time_travel/techno/                                     1
# time_travel/super/dystopian/monster/                                1
# space/robot/time_travel/super/fantasy/monster/                      1
# fantasy/techno/                                                     1
# fantasy/monster/techno/                                             1
# space/time_travel/dystopian/fantasy/monster/techno/                 1
# alien/space/robot/time_travel/super/fantasy/monster/techno/         1
# robot/super/                                                        1
# super/dystopian/monster/techno/                                     1
# alien/space/time_travel/super/fantasy/                              1
# space/robot/fantasy/techno/                                         1
# alien/super/dystopian/techno/                                       1
# space/robot/time_travel/fantasy/monster/techno/                     1
# alien/time_travel/super/dystopian/fantasy/monster/techno/           1
# Name: sub_genres, dtype: int64

# %%
# number of empty sub_genres remaining
(df_movies_sff['sub_genres'].values == '').sum()
# Out:
# 21

# %%
# we still need to do some work here... label the rest of the movies with sub_genres
df_movies_sff.loc[df_movies_sff['sub_genres'].values=='']
# Out:
#       belongs_to_collection    budget  \
# 4805                    NaN       NaN
# 9421                    NaN       NaN
# 11324                   NaN       NaN
# 11584                   NaN       NaN
# 13024                   NaN       NaN
# 14442                   NaN       NaN
# 15360                   NaN       NaN
# 16391                   NaN       NaN
# 19253                   NaN       NaN
# 20117                   NaN       NaN
# 22304                   NaN    600000
# 22814                   NaN  20000000
# 22818                   NaN       NaN
# 25590                   NaN       NaN
# 26948                   NaN       NaN
# 34713                   NaN       NaN
# 39197                   NaN   2004384
# 39235                   NaN       NaN
# 43226                   NaN       NaN
# 43480                   NaN       NaN
# 43963                   NaN       NaN
#
#                                                   genres  \
# 4805   [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 9421   [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 11324  [{'id': 12, 'name': 'Adventure'}, {'id': 27, '...
# 11584  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 13024  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 14442  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 15360  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 16391  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 19253  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 20117  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 22304  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 22814  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 22818  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 25590  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 26948  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 34713  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 39197           [{'id': 878, 'name': 'Science Fiction'}]
# 39235  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 43226  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
# 43480  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 43963  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
#
#                             homepage      id original_language  \
# 4805                             NaN   33356                en
# 9421                             NaN  100594                fi
# 11324                            NaN    3593                en
# 11584                            NaN    3024                en
# 13024                            NaN    2397                en
# 14442                            NaN  112687                en
# 15360                            NaN    8652                ko
# 16391                            NaN   21136                ja
# 19253                            NaN   49084                en
# 20117                            NaN  177522                fi
# 22304          http://www.fase7.com/   69278                es
# 22814  http://www.lovestory2050.com/   20493                hi
# 22818                            NaN  418029                es
# 25590                            NaN  158828                en
# 26948                            NaN   62347                it
# 34713                            NaN  238307                ru
# 39197         http://brandnew-u.com/  343724                en
# 39235                            NaN   89662                en
# 43226                            NaN  381449                de
# 43480                            NaN  236053                tr
# 43963                            NaN  362844                en
#
#                                                 overview popularity  \
# 4805   The exploration of the effects of an unexpecte...   0.866004
# 9421                                                 NaN   0.203204
# 11324  Four explorers are summoned to Peru by the bri...   0.662919
# 11584                                 No overview found.   0.424452
# 13024                                 No overview found.    1.68743
# 14442  The waters surrounding an island become contam...   0.842879
# 15360  In the aftermath of a car crash, a man discove...   0.862305
# 16391  The Taste of Tea director Katsuhito Ishii coll...    1.49222
# 19253  A French comedy with comedians Eric &amp; Ramz...     2.6692
# 20117                                                NaN   0.073825
# 22304  Inside a quarantined apartment building a man ...    1.98512
# 22814                                 No overview found.   0.304988
# 22818                                                NaN   0.001884
# 25590  Incited by a disillusioned young man who has d...   0.016023
# 26948  The year is 2049. 200 years after the great Ca...   0.469421
# 34713  A musical partially based on a sci-fi novel "T...   0.051647
# 39197  Identicals is a highly unconventional romantic...   1.090345
# 39235  A stone-encrusted body is unearthed at Pompeii...   0.259001
# 43226  15 years ago the sea at the coast of Windholm ...   0.452123
# 43480                                                NaN   0.219218
# 43963                                                NaN   0.002603
#
#                                              poster_path  \
# 4805   http://image.tmdb.org/t/p/w185//pJ5ftKZSO7by9G...
# 9421   http://image.tmdb.org/t/p/w185//juhxfyFyQ7MXFL...
# 11324  http://image.tmdb.org/t/p/w185//5bUdwNdumc2cPz...
# 11584  http://image.tmdb.org/t/p/w185//8byiRQ9kv2TUGn...
# 13024  http://image.tmdb.org/t/p/w185//zU9hKyOjiR8NUp...
# 14442  http://image.tmdb.org/t/p/w185//tuyJVMke3D9esB...
# 15360  http://image.tmdb.org/t/p/w185//fwGaqe9YWSHSQZ...
# 16391  http://image.tmdb.org/t/p/w185//vLCLqZugcLEhoP...
# 19253  http://image.tmdb.org/t/p/w185//rdPGeN2PXbmhBh...
# 20117  http://image.tmdb.org/t/p/w185//oAUq5rhZEjDz9h...
# 22304  http://image.tmdb.org/t/p/w185//fjl7JyHHQIiZfL...
# 22814  http://image.tmdb.org/t/p/w185//og9uH3LXux775c...
# 22818  http://image.tmdb.org/t/p/w185//k0YJzGkxXjzgfU...
# 25590  http://image.tmdb.org/t/p/w185//xctDqlwRd2SeIR...
# 26948  http://image.tmdb.org/t/p/w185//nMX57uQidKmpBy...
# 34713  http://image.tmdb.org/t/p/w185//uvtsTpqy60si6X...
# 39197  http://image.tmdb.org/t/p/w185//rtiKN28y3J1NVE...
# 39235  http://image.tmdb.org/t/p/w185//spOquowSZMTt1J...
# 43226  http://image.tmdb.org/t/p/w185//hPFwDTjlyHNot1...
# 43480  http://image.tmdb.org/t/p/w185//30Lw7lbSXwm9NU...
# 43963  http://image.tmdb.org/t/p/w185//pe2FQ7L96zkBaL...
#
#                                     production_companies     ...      \
# 4805   [{'name': 'British Film Institute (BFI)', 'id'...     ...
# 9421                                                  []     ...
# 11324          [{'name': 'Paramount Pictures', 'id': 4}]     ...
# 11584                                                 []     ...
# 13024                                                 []     ...
# 14442  [{'name': 'Tigon British Film Productions', 'i...     ...
# 15360  [{'name': 'Kim Ki-Duk Film', 'id': 684}, {'nam...     ...
# 16391           [{'name': 'Aoi Promotion', 'id': 39804}]     ...
# 19253                                                 []     ...
# 20117                                                 []     ...
# 22304  [{'name': 'Instituto Nacional de Cine y Artes ...     ...
# 22814            [{'name': 'Baweja Movies', 'id': 3786}]     ...
# 22818  [{'name': 'TOHO', 'id': 51905}, {'name': 'subu...     ...
# 25590  [{'name': 'Box Office Spectaculars', 'id': 4758}]     ...
# 26948                                                 []     ...
# 34713  [{'name': 'Lenfilm', 'id': 10845}, {'name': 'G...     ...
# 39197  [{'name': 'Hot Property Films', 'id': 4304}, {...     ...
# 39235  [{'name': 'Robert E. Kent Productions', 'id': ...     ...
# 43226  [{'name': 'Rundfunk Berlin-Brandenburg (RBB)',...     ...
# 43480                                                 []     ...
# 43963                                                 []     ...
#
#                                         spoken_languages    status  \
# 4805            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9421              [{'iso_639_1': 'fi', 'name': 'suomi'}]  Released
# 11324           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11584           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 13024           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14442           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15360           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 16391               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 19253                                                 []  Released
# 20117             [{'iso_639_1': 'fi', 'name': 'suomi'}]  Released
# 22304           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 22814            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 22818                                                 []  Released
# 25590  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 26948  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 34713           [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 39197           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 39235  [{'iso_639_1': 'it', 'name': 'Italiano'}, {'is...  Released
# 43226           [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released
# 43480            [{'iso_639_1': 'tr', 'name': 'Türkçe'}]  Released
# 43963           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 4805                                                 NaN
# 9421                                                 NaN
# 11324                                                NaN
# 11584                                                NaN
# 13024                                                NaN
# 14442              An ecological nightmare gone berserk!
# 15360                     A dream is a dream is a dream.
# 16391                                                NaN
# 19253                                                NaN
# 20117                                                NaN
# 22304                                                NaN
# 22814                                                NaN
# 22818                                                NaN
# 25590                                          Right-On!
# 26948                                                NaN
# 34713                                                NaN
# 39197                None of us are as unique as we hope
# 39235  Entombed for eons - turned to stone - seeking ...
# 43226                                                NaN
# 43480                                                NaN
# 43963                                                NaN
#
#                                              title  video vote_average  \
# 4805                                     The Falls  False          8.0
# 9421                              The Book of Fate  False          3.5
# 11324                                  Dr. Cyclops  False          6.1
# 11584  The Strange Case of Dr. Jekyll and Mr. Hyde  False          0.0
# 13024                                      Fallout  False          0.0
# 14442                                    Doomwatch  False          7.4
# 15360                                        Dream  False          6.2
# 16391              Funky Forest: The First Contact  False          6.0
# 19253                                        Steak  False          5.1
# 20117      Lipton Cockton in the Shadows of Sodoma  False          6.0
# 22304                                      Phase 7  False          4.9
# 22814                              Love Story 2050  False          3.6
# 22818                                     Ultraman  False          0.0
# 25590                 An American Hippie in Israel  False          5.5
# 26948                                Precious Find  False          4.3
# 34713                       The Isle of Lost Ships  False          3.0
# 39197                                   Identicals  False          4.1
# 39235                    Curse of the Faceless Man  False          5.3
# 43226                              We are the tide  False          5.0
# 43480                                    Japon İşi  False          6.3
# 43963                                     Survivor  False          0.0
#
#       vote_count  year return  sub_genres
# 4805           9  1980    NaN
# 9421           2  2003    NaN
# 11324         15  1940    NaN
# 11584          0  1968    NaN
# 13024          0  1998    NaN
# 14442          7  1972    NaN
# 15360         11  2008    NaN
# 16391         15  2005    NaN
# 19253         51  2007    NaN
# 20117          1  1995    NaN
# 22304         23  2011    NaN
# 22814          8  2008   0.25
# 22818          0  1967    NaN
# 25590          2  1972    NaN
# 26948          2  1996    NaN
# 34713          1  1987    NaN
# 39197         13  2015    NaN
# 39235          6  1958    NaN
# 43226          1  2016    NaN
# 43480          2  1987    NaN
# 43963          0  1999    NaN
#
# [21 rows x 24 columns]

# %%
df_movies_sff.to_csv('movies_metadata_scififantasy_12-1-2018.csv',sep=',')
